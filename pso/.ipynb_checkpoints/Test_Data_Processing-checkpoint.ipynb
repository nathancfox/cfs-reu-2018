# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
df = pd.read_csv('reported.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  num_features  g_fitness  a_fitness
# 0           0          80.0   0.687912   0.687912
# 1           1          80.0   0.687912   0.687912
# 2           2          76.0   0.692122   0.692122
# 3           3          73.0   0.695280   0.695280
# 4           4          67.0   0.701596   0.701596

# %%
df.shape
# Out:
# (200, 4)

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.head()
# Out:
#    num_features  g_fitness  a_fitness
# 0          80.0   0.687912   0.687912
# 1          80.0   0.687912   0.687912
# 2          76.0   0.692122   0.692122
# 3          73.0   0.695280   0.695280
# 4          67.0   0.701596   0.701596

# %%
fig = plt.figure(figsize=(20, 20))
ax1 = fig.add_subplot(211)
ax1.plot(df.index, df['num_features'], 'ro')
ax1.legend()
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Number of Features in abinary')
ax2 = fig.add_subplot(212)
ax2.plot(df.index, df['g_fitness'], 'bx')
ax2.plot(df.index, df['a_fitness'], 'gv')
ax2.legend()
ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Fitness Function')
plt.show()
