# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
df = pd.read_csv('../Tuning_VBounds/analysis/even_split_results.txt', skiprows=[1], sep = ':')

# %%
df
# Out:
#     Directory                                   Nonzero    Size    Ratio
# 0   00_vbounds_-6.0_-2.0                              57     204  0.2794
# 1   01_vbounds_-5.8_-1.8                              61     204  0.2990
# 2   02_vbounds_-5.6_-1.6                              56     204  0.2745
# 3   03_vbounds_-5.4_-1.4                              60     204  0.2941
# 4   04_vbounds_-5.2_-1.2                              58     204  0.2843
# 5   05_vbounds_-5.0_-1.0                              53     204  0.2598
# 6   06_vbounds_-4.8_-0.8                              60     204  0.2941
# 7   07_vbounds_-4.6_-0.6                              55     204  0.2696
# 8   08_vbounds_-4.4_-0.4                              60     204  0.2941
# 9   09_vbounds_-4.2_-0.2                              59     204  0.2892
# 10  10_vbounds_-4.0_+0.0                              60     204  0.2941
# 11  11_vbounds_-3.8_+0.2                              58     204  0.2843
# 12  12_vbounds_-3.6_+0.4                              58     204  0.2843
# 13  13_vbounds_-3.4_+0.6                              58     204  0.2843
# 14  14_vbounds_-3.2_+0.8                              57     204  0.2794
# 15  15_vbounds_-3.0_+1.0                              53     204  0.2598
# 16  16_vbounds_-2.8_+1.2                              58     204  0.2843
# 17  17_vbounds_-2.6_+1.4                              56     204  0.2745
# 18  18_vbounds_-2.4_+1.6                              53     204  0.2598
# 19  19_vbounds_-2.2_+1.8                              53     204  0.2598
# 20  20_vbounds_-2.0_+2.0                              58     204  0.2843
# 21  21_vbounds_-1.8_+2.2                              58     204  0.2843
# 22  22_vbounds_-1.6_+2.4                              56     204  0.2745
# 23  23_vbounds_-1.4_+2.6                              58     204  0.2843
# 24  24_vbounds_-1.2_+2.8                              58     204  0.2843
# 25  25_vbounds_-1.0_+3.0                              62     204  0.3039
# 26  26_vbounds_-0.8_+3.2                              59     204  0.2892
# 27  27_vbounds_-0.6_+3.4                              60     204  0.2941
# 28  28_vbounds_-0.4_+3.6                              58     204  0.2843
# 29  29_vbounds_-0.2_+3.8                              62     204  0.3039
# 30  30_vbounds_+0.0_+4.0                              54     204  0.2647
# 31  31_vbounds_+0.2_+4.2                              58     204  0.2843
# 32  32_vbounds_+0.4_+4.4                              55     204  0.2696
# 33  33_vbounds_+0.6_+4.6                              58     204  0.2843
# 34  34_vbounds_+0.8_+4.8                              57     204  0.2794
# 35  35_vbounds_+1.0_+5.0                              53     204  0.2598
# 36  36_vbounds_+1.2_+5.2                              58     204  0.2843
# 37  37_vbounds_+1.4_+5.4                              59     204  0.2892
# 38  38_vbounds_+1.6_+5.6                              61     204  0.2990
# 39  39_vbounds_+1.8_+5.8                              57     204  0.2794
# 40  40_vbounds_+2.0_+6.0                              57     204  0.2794

# %%
df.dtypes
# Out:
# Directory                                     object
#  Nonzero                                       int64
#  Size                                          int64
#  Ratio                                       float64
# dtype: object

# %% [markdown]
# Holy crap, it parsed my terrible file perfectly.

# %%
df2 = pd.read_csv('../Tuning_VBounds/analysis/raw_data.csv', sep=',')

# %%
df2
# Out:
#     index  vmin  vmax  num_of_features  a_fitness  training_accuracy  \
# 0       0  -6.0  -2.0                2     0.8457             0.8098
# 1       1  -5.8  -1.8                2     0.8260             0.7851
# 2       2  -5.6  -1.6                2     0.8338             0.7948
# 3       3  -5.4  -1.4                2     0.8295             0.7895
# 4       4  -5.2  -1.2                2     0.8376             0.7996
# 5       5  -5.0  -1.0                2     0.8571             0.8240
# 6       6  -4.8  -0.8                2     0.8217             0.7798
# 7       7  -4.6  -0.6                2     0.8416             0.8047
# 8       8  -4.4  -0.4                2     0.8406             0.8033
# 9       9  -4.2  -0.2                2     0.8212             0.7792
# 10     10  -4.0   0.0                2     0.8299             0.7900
# 11     11  -3.8   0.2                2     0.8279             0.7876
# 12     12  -3.6   0.4                2     0.8530             0.8189
# 13     13  -3.4   0.6                2     0.8324             0.7931
# 14     14  -3.2   0.8                2     0.8419             0.8050
# 15     15  -3.0   1.0                2     0.8452             0.8092
# 16     16  -2.8   1.2                3     0.8365             0.7996
# 17     17  -2.6   1.4                6     0.8335             0.7998
# 18     18  -2.4   1.6                5     0.8263             0.7894
# 19     19  -2.2   1.8               17     0.8098             0.7847
# 20     20  -2.0   2.0               45     0.7254             0.7159
# 21     21  -1.8   2.2               57     0.7128             0.7159
# 22     22  -1.6   2.4               71     0.7060             0.7259
# 23     23  -1.4   2.6               77     0.6917             0.7159
# 24     24  -1.2   2.8               73     0.6959             0.7159
# 25     25  -1.0   3.0               78     0.6750             0.6964
# 26     26  -0.8   3.2               78     0.6866             0.7108
# 27     27  -0.6   3.4               78     0.6825             0.7057
# 28     28  -0.4   3.6               76     0.6928             0.7159
# 29     29  -0.2   3.8               72     0.6813             0.6964
# 30     30   0.0   4.0               78     0.7065             0.7357
# 31     31   0.2   4.2               77     0.6917             0.7159
# 32     32   0.4   4.4               77     0.7036             0.7308
# 33     33   0.6   4.6               75     0.6938             0.7159
# 34     34   0.8   4.8               78     0.6947             0.7211
# 35     35   1.0   5.0               79     0.7093             0.7406
# 36     36   1.2   5.2               80     0.6885             0.7159
# 37     37   1.4   5.4               78     0.6866             0.7108
# 38     38   1.6   5.6               77     0.6798             0.7010
# 39     39   1.8   5.8               76     0.6968             0.7211
# 40     40   2.0   6.0               74     0.6989             0.7211
#
#     test_accuracy
# 0          0.8183
# 1          0.7714
# 2          0.6667
# 3          0.7733
# 4          0.8117
# 5          0.6717
# 6          0.8133
# 7          0.7650
# 8          0.7733
# 9          0.7683
# 10         0.7533
# 11         0.6967
# 12         0.7200
# 13         0.6750
# 14         0.6683
# 15         0.7283
# 16         0.7367
# 17         0.6917
# 18         0.5983
# 19         0.6350
# 20         0.7367
# 21         0.7367
# 22         0.7000
# 23         0.7367
# 24         0.7367
# 25         0.8067
# 26         0.7550
# 27         0.7733
# 28         0.7367
# 29         0.8067
# 30         0.6567
# 31         0.7367
# 32         0.6783
# 33         0.7367
# 34         0.7183
# 35         0.6350
# 36         0.7367
# 37         0.7550
# 38         0.7914
# 39         0.7183
# 40         0.7183

# %%
dfFull = pd.concat([df, df2], axis=1)

# %%
dfFull.head()
# Out:
#    Directory                                   Nonzero    Size    Ratio  \
# 0  00_vbounds_-6.0_-2.0                              57     204  0.2794
# 1  01_vbounds_-5.8_-1.8                              61     204  0.2990
# 2  02_vbounds_-5.6_-1.6                              56     204  0.2745
# 3  03_vbounds_-5.4_-1.4                              60     204  0.2941
# 4  04_vbounds_-5.2_-1.2                              58     204  0.2843
#
#    index  vmin  vmax  num_of_features  a_fitness  training_accuracy  \
# 0      0  -6.0  -2.0                2     0.8457             0.8098
# 1      1  -5.8  -1.8                2     0.8260             0.7851
# 2      2  -5.6  -1.6                2     0.8338             0.7948
# 3      3  -5.4  -1.4                2     0.8295             0.7895
# 4      4  -5.2  -1.2                2     0.8376             0.7996
#
#    test_accuracy
# 0         0.8183
# 1         0.7714
# 2         0.6667
# 3         0.7733
# 4         0.8117

# %%
dfFull.columns
# Out:
# Index(['Directory', 'Nonzero', 'Size', 'Ratio', 'index', 'vmin', 'vmax',
#        'num_of_features', 'a_fitness', 'training_accuracy', 'test_accuracy'],
#       dtype='object')

# %%
newcols = []
for col in dfFull.columns:
    newcols.append(col.strip())
dfFull.columns = newcols

# %%
dfFull.columns
# Out:
# Index(['Directory', 'Nonzero', 'Size', 'Ratio', 'index', 'vmin', 'vmax',
#        'num_of_features', 'a_fitness', 'training_accuracy', 'test_accuracy'],
#       dtype='object')

# %%
plt.scatter(dfFull['Ratio'], dfFull['test_accuracy'])
plt.xlabel('Hits/Total Labels')
plt.ylabel('TEST Score')
plt.title('Test Accuracy vs. Fraction of Hits in y_train')
plt.savefig('../lab_notebooks/cfs_notebook_files/Even_Split_Check_SCAT_test_score_ratio.svg')

# %%
dfFull['Ratio'].corr(dfFull['test_accuracy'])
# Out:
# 0.7777137588750695

# %%
plt.scatter(dfFull['Ratio'], dfFull['training_accuracy'])
plt.xlabel('Hits/Total Labels')
plt.ylabel('TRAIN Score')
plt.title('Training Accuracy vs. Fraction of Hits in y_train')
plt.savefig('../lab_notebooks/cfs_notebook_files/Even_Split_Check_SCAT_train_score_ratio.svg')

# %%
dfFull['Ratio'].corr(dfFull['training_accuracy'])
# Out:
# -0.33036668560982235

# %%
dfFull['test_accuracy'].corr(dfFull['training_accuracy'])
# Out:
# -0.1796296335516965

# %%
dfFull[dfFull['training_accuracy'] < 0.76]['Ratio'].corr(dfFull[dfFull['training_accuracy'] < 0.76]['training_accuracy'])
# Out:
# -0.9999042008389337

# %%
dfFull[dfFull['training_accuracy'] < 0.76]['Ratio'].corr(dfFull[dfFull['training_accuracy'] < 0.76]['test_accuracy'])
# Out:
# 0.9984908868077705

# %%
plt.scatter(dfFull[dfFull['training_accuracy'] < 0.76]['Ratio'], dfFull[dfFull['training_accuracy'] < 0.76]['test_accuracy'])
plt.xlabel('Hits/Total Labels')
plt.ylabel('TEST Score')
plt.title('Test Accuracy vs. Hits Ratio - Subset : Train Score < 0.76')
plt.savefig('../lab_notebooks/cfs_notebook_files/Even_Split_Check_SCAT_SUBSET_test_score_ratio.svg')

# %%
dfFull[dfFull['training_accuracy'] < 0.76]
# Out:
#                                     Directory  Nonzero  Size   Ratio  index  \
# 20  20_vbounds_-2.0_+2.0                            58   204  0.2843     20
# 21  21_vbounds_-1.8_+2.2                            58   204  0.2843     21
# 22  22_vbounds_-1.6_+2.4                            56   204  0.2745     22
# 23  23_vbounds_-1.4_+2.6                            58   204  0.2843     23
# 24  24_vbounds_-1.2_+2.8                            58   204  0.2843     24
# 25  25_vbounds_-1.0_+3.0                            62   204  0.3039     25
# 26  26_vbounds_-0.8_+3.2                            59   204  0.2892     26
# 27  27_vbounds_-0.6_+3.4                            60   204  0.2941     27
# 28  28_vbounds_-0.4_+3.6                            58   204  0.2843     28
# 29  29_vbounds_-0.2_+3.8                            62   204  0.3039     29
# 30  30_vbounds_+0.0_+4.0                            54   204  0.2647     30
# 31  31_vbounds_+0.2_+4.2                            58   204  0.2843     31
# 32  32_vbounds_+0.4_+4.4                            55   204  0.2696     32
# 33  33_vbounds_+0.6_+4.6                            58   204  0.2843     33
# 34  34_vbounds_+0.8_+4.8                            57   204  0.2794     34
# 35  35_vbounds_+1.0_+5.0                            53   204  0.2598     35
# 36  36_vbounds_+1.2_+5.2                            58   204  0.2843     36
# 37  37_vbounds_+1.4_+5.4                            59   204  0.2892     37
# 38  38_vbounds_+1.6_+5.6                            61   204  0.2990     38
# 39  39_vbounds_+1.8_+5.8                            57   204  0.2794     39
# 40  40_vbounds_+2.0_+6.0                            57   204  0.2794     40
#
#     vmin  vmax  num_of_features  a_fitness  training_accuracy  test_accuracy
# 20  -2.0   2.0               45     0.7254             0.7159         0.7367
# 21  -1.8   2.2               57     0.7128             0.7159         0.7367
# 22  -1.6   2.4               71     0.7060             0.7259         0.7000
# 23  -1.4   2.6               77     0.6917             0.7159         0.7367
# 24  -1.2   2.8               73     0.6959             0.7159         0.7367
# 25  -1.0   3.0               78     0.6750             0.6964         0.8067
# 26  -0.8   3.2               78     0.6866             0.7108         0.7550
# 27  -0.6   3.4               78     0.6825             0.7057         0.7733
# 28  -0.4   3.6               76     0.6928             0.7159         0.7367
# 29  -0.2   3.8               72     0.6813             0.6964         0.8067
# 30   0.0   4.0               78     0.7065             0.7357         0.6567
# 31   0.2   4.2               77     0.6917             0.7159         0.7367
# 32   0.4   4.4               77     0.7036             0.7308         0.6783
# 33   0.6   4.6               75     0.6938             0.7159         0.7367
# 34   0.8   4.8               78     0.6947             0.7211         0.7183
# 35   1.0   5.0               79     0.7093             0.7406         0.6350
# 36   1.2   5.2               80     0.6885             0.7159         0.7367
# 37   1.4   5.4               78     0.6866             0.7108         0.7550
# 38   1.6   5.6               77     0.6798             0.7010         0.7914
# 39   1.8   5.8               76     0.6968             0.7211         0.7183
# 40   2.0   6.0               74     0.6989             0.7211         0.7183

# %%
(dfFull[dfFull['training_accuracy'] < 0.76] == dfFull[(dfFull['vmax']+dfFull['vmin'])/2 >= 0.0]).all()
# Out:
# Directory            True
# Nonzero              True
# Size                 True
# Ratio                True
# index                True
# vmin                 True
# vmax                 True
# num_of_features      True
# a_fitness            True
# training_accuracy    True
# test_accuracy        True
# dtype: bool

# %%
dfFull[dfFull['training_accuracy'] < 0.76]['test_accuracy'].corr(dfFull[dfFull['training_accuracy'] < 0.76]['training_accuracy'])
# Out:
# -0.9984928428464795

# %%
dfFull[dfFull['training_accuracy'] > 0.76]['test_accuracy'].corr(dfFull[dfFull['training_accuracy'] > 0.76]['training_accuracy'])
# Out:
# -0.05153764167052053

# %%
dfFull[dfFull['training_accuracy'] > 0.76]['test_accuracy'].corr(dfFull[dfFull['training_accuracy'] > 0.76]['Ratio'])
# Out:
# 0.6467605705361831

# %%
dfFull[dfFull['training_accuracy'] > 0.76]['Ratio'].corr(dfFull[dfFull['training_accuracy'] > 0.76]['training_accuracy'])
# Out:
# -0.39117756990328345

# %% [markdown]
# ---

# %%
dfneg2 = pd.read_csv('../Tuning_VBounds_Range/vbounds_range_center-2/analysis/even_split_results.txt', skiprows=[1], sep = ':')

# %%
dfneg2
# Out:
#     Directory                                   Nonzero    Size    Ratio
# 0   01_vcenter_-2.0_vrange_+0.4                       55     204  0.2696
# 1   02_vcenter_-2.0_vrange_+0.8                       63     204  0.3088
# 2   03_vcenter_-2.0_vrange_+1.2                       51     204  0.2500
# 3   04_vcenter_-2.0_vrange_+1.6                       57     204  0.2794
# 4   05_vcenter_-2.0_vrange_+2.0                       58     204  0.2843
# 5   06_vcenter_-2.0_vrange_+2.4                       58     204  0.2843
# 6   07_vcenter_-2.0_vrange_+2.8                       49     204  0.2402
# 7   08_vcenter_-2.0_vrange_+3.2                       60     204  0.2941
# 8   09_vcenter_-2.0_vrange_+3.6                       60     204  0.2941
# 9   10_vcenter_-2.0_vrange_+4.0                       56     204  0.2745
# 10  11_vcenter_-2.0_vrange_+4.4                       61     204  0.2990
# 11  12_vcenter_-2.0_vrange_+4.8                       56     204  0.2745
# 12  13_vcenter_-2.0_vrange_+5.2                       58     204  0.2843
# 13  14_vcenter_-2.0_vrange_+5.6                       56     204  0.2745
# 14  15_vcenter_-2.0_vrange_+6.0                       53     204  0.2598
# 15  16_vcenter_-2.0_vrange_+6.4                       59     204  0.2892
# 16  17_vcenter_-2.0_vrange_+6.8                       58     204  0.2843
# 17  18_vcenter_-2.0_vrange_+7.2                       55     204  0.2696
# 18  19_vcenter_-2.0_vrange_+7.6                       59     204  0.2892

# %%
dfneg2.dtypes
# Out:
# Directory                                     object
#  Nonzero                                       int64
#  Size                                          int64
#  Ratio                                       float64
# dtype: object

# %%
dfneg2_2 = pd.read_csv('../Tuning_VBounds_Range/vbounds_range_center-2/analysis/raw_data.csv', sep=',')

# %%
dfneg2_2
# Out:
#     index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 0       0     -2.0     0.0   NaN   NaN              NaN        NaN
# 1       1     -2.0     0.4  -2.2  -1.8              1.0     0.8223
# 2       2     -2.0     0.8  -2.4  -1.6              2.0     0.8015
# 3       3     -2.0     1.2  -2.6  -1.4              3.0     0.8516
# 4       4     -2.0     1.6  -2.8  -1.2              2.0     0.8309
# 5       5     -2.0     2.0  -3.0  -1.0              2.0     0.8366
# 6       6     -2.0     2.4  -3.2  -0.8              1.0     0.8186
# 7       7     -2.0     2.8  -3.4  -0.6              2.0     0.8531
# 8       8     -2.0     3.2  -3.6  -0.4              2.0     0.8211
# 9       9     -2.0     3.6  -3.8  -0.2              2.0     0.8089
# 10     10     -2.0     4.0  -4.0   0.0              2.0     0.8422
# 11     11     -2.0     4.4  -4.2   0.2              2.0     0.8403
# 12     12     -2.0     4.8  -4.4   0.4              3.0     0.8433
# 13     13     -2.0     5.2  -4.6   0.6              2.0     0.8374
# 14     14     -2.0     5.6  -4.8   0.8              2.0     0.8418
# 15     15     -2.0     6.0  -5.0   1.0              2.0     0.8445
# 16     16     -2.0     6.4  -5.2   1.2              4.0     0.8306
# 17     17     -2.0     6.8  -5.4   1.4              2.0     0.8336
# 18     18     -2.0     7.2  -5.6   1.6              3.0     0.8594
# 19     19     -2.0     7.6  -5.8   1.8              5.0     0.8299
#
#     training_score  test_score
# 0              NaN         NaN
# 1           0.7792      0.7600
# 2           0.7545      0.8300
# 3           0.8185      0.5429
# 4           0.7912      0.6533
# 5           0.7984      0.7200
# 6           0.7746      0.7367
# 7           0.8190      0.6883
# 8           0.7790      0.7133
# 9           0.7638      0.8133
# 10          0.8053      0.7250
# 11          0.8030      0.7914
# 12          0.8081      0.7083
# 13          0.7993      0.7367
# 14          0.8048      0.7250
# 15          0.8083      0.5900
# 16          0.7935      0.7300
# 17          0.7946      0.7367
# 18          0.8282      0.6450
# 19          0.7939      0.7183

# %%
dfneg2Full = pd.concat([dfneg2, dfneg2_2], axis=1)

# %%
dfneg2Full.head()
# Out:
#    Directory                                   Nonzero    Size    Ratio  \
# 0  01_vcenter_-2.0_vrange_+0.4                     55.0   204.0  0.2696
# 1  02_vcenter_-2.0_vrange_+0.8                     63.0   204.0  0.3088
# 2  03_vcenter_-2.0_vrange_+1.2                     51.0   204.0  0.2500
# 3  04_vcenter_-2.0_vrange_+1.6                     57.0   204.0  0.2794
# 4  05_vcenter_-2.0_vrange_+2.0                     58.0   204.0  0.2843
#
#    index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 0      0     -2.0     0.0   NaN   NaN              NaN        NaN
# 1      1     -2.0     0.4  -2.2  -1.8              1.0     0.8223
# 2      2     -2.0     0.8  -2.4  -1.6              2.0     0.8015
# 3      3     -2.0     1.2  -2.6  -1.4              3.0     0.8516
# 4      4     -2.0     1.6  -2.8  -1.2              2.0     0.8309
#
#    training_score  test_score
# 0             NaN         NaN
# 1          0.7792      0.7600
# 2          0.7545      0.8300
# 3          0.8185      0.5429
# 4          0.7912      0.6533

# %%
dfneg2Full.drop(0, axis=0, inplace=True)

# %%
dfneg2Full.head(1)
# Out:
#    Directory                                   Nonzero    Size    Ratio  \
# 1  02_vcenter_-2.0_vrange_+0.8                     63.0   204.0  0.3088
#
#    index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 1      1     -2.0     0.4  -2.2  -1.8              1.0     0.8223
#
#    training_score  test_score
# 1          0.7792        0.76

# %%
dfneg2Full.columns
# Out:
# Index(['Directory                                ', ' Nonzero ', ' Size ',
#        ' Ratio', 'index', 'vcenter', 'vrange', 'vmin', 'vmax',
#        'num_of_features', 'a_fitness', 'training_score', 'test_score'],
#       dtype='object')

# %%
newcols = []
for col in dfneg2Full.columns:
    newcols.append(col.strip())
dfneg2Full.columns = newcols

# %%
dfneg2Full.columns
# Out:
# Index(['Directory', 'Nonzero', 'Size', 'Ratio', 'index', 'vcenter', 'vrange',
#        'vmin', 'vmax', 'num_of_features', 'a_fitness', 'training_score',
#        'test_score'],
#       dtype='object')

# %%
plt.scatter(dfneg2Full['Ratio'], dfneg2Full['test_score'])

# %%
dfneg2Full['Ratio'].corr(dfneg2Full['test_score'])
# Out:
# -0.32051456835412645

# %%
plt.scatter(dfneg2Full['Ratio'], dfneg2Full['training_score'])

# %%
dfneg2Full['Ratio'].corr(dfneg2Full['training_score'])
# Out:
# 0.40158738871156663

# %%
dfneg2subset = dfneg2Full[(dfneg2Full['vmax']+dfneg2Full['vmin']) / 2 > 0.0]

# %%
dfneg2subset
# Out:
# Empty DataFrame
# Columns: [Directory, Nonzero, Size, Ratio, index, vcenter, vrange, vmin, vmax, num_of_features, a_fitness, training_score, test_score]
# Index: []

# %%
plt.scatter(dfneg2Full['test_score'], dfneg2Full['training_score'])

# %%
dfneg2Full['test_score'].corr(dfneg2Full['training_score'])
# Out:
# -0.6958054549997705

# %% [markdown]
# In the first dataset I looked at, there was a perfect correlation between test_accuracy, training_accuracy, and Ratio as long as the vcenter > 0.0. If vcenter < 0.0, there was no correlation between training_accuracy and test_accuracy and small to moderate correlations between training/test_accuracy and Ratio. In the second dataset, NONE of the observations had vcenter < 0.0. However, the correlations were still moderate, but very different than the first dataset.

# %% [markdown]
# ## Third Dataset - vcenter = 2.0

# %%
dfpos2 = pd.read_csv('../Tuning_VBounds_Range/vbounds_range_center2/analysis/even_split_results.txt', skiprows=[1], sep = ':')

# %%
dfpos2
# Out:
#     Directory                                   Nonzero    Size    Ratio
# 0   01_vcenter_2.0_vrange_+0.4                        61     204  0.2990
# 1   02_vcenter_2.0_vrange_+0.8                        55     204  0.2696
# 2   03_vcenter_2.0_vrange_+1.2                        58     204  0.2843
# 3   04_vcenter_2.0_vrange_+1.6                        61     204  0.2990
# 4   05_vcenter_2.0_vrange_+2.0                        57     204  0.2794
# 5   06_vcenter_2.0_vrange_+2.4                        60     204  0.2941
# 6   07_vcenter_2.0_vrange_+2.8                        55     204  0.2696
# 7   08_vcenter_2.0_vrange_+3.2                        53     204  0.2598
# 8   09_vcenter_2.0_vrange_+3.6                        60     204  0.2941
# 9   10_vcenter_2.0_vrange_+4.0                        55     204  0.2696
# 10  11_vcenter_2.0_vrange_+4.4                        57     204  0.2794
# 11  12_vcenter_2.0_vrange_+4.8                        49     204  0.2402
# 12  13_vcenter_2.0_vrange_+5.2                        64     204  0.3137
# 13  14_vcenter_2.0_vrange_+5.6                        55     204  0.2696
# 14  15_vcenter_2.0_vrange_+6.0                        61     204  0.2990
# 15  16_vcenter_2.0_vrange_+6.4                        61     204  0.2990
# 16  17_vcenter_2.0_vrange_+6.8                        55     204  0.2696
# 17  18_vcenter_2.0_vrange_+7.2                        54     204  0.2647
# 18  19_vcenter_2.0_vrange_+7.6                        59     204  0.2892

# %%
dfpos2.dtypes
# Out:
# Directory                                     object
#  Nonzero                                       int64
#  Size                                          int64
#  Ratio                                       float64
# dtype: object

# %%
dfpos2_2 = pd.read_csv('../Tuning_VBounds_Range/vbounds_range_center2/analysis/raw_data.csv', sep=',')

# %%
dfpos2_2
# Out:
#     index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 0       0      2.0     0.0   NaN   NaN              NaN        NaN
# 1       1      2.0     0.4   1.8   2.2             78.0     0.6787
# 2       2      2.0     0.8   1.6   2.4             78.0     0.7026
# 3       3      2.0     1.2   1.4   2.6             79.0     0.6896
# 4       4      2.0     1.6   1.2   2.8             72.0     0.6850
# 5       5      2.0     2.0   1.0   3.0             80.0     0.6926
# 6       6      2.0     2.4   0.8   3.2             79.0     0.6814
# 7       7      2.0     2.8   0.6   3.4             74.0     0.7068
# 8       8      2.0     3.2   0.4   3.6             79.0     0.7093
# 9       9      2.0     3.6   0.2   3.8             78.0     0.6825
# 10     10      2.0     4.0   0.0   4.0             72.0     0.7089
# 11     11      2.0     4.4  -0.2   4.2             79.0     0.6937
# 12     12      2.0     4.8  -0.4   4.4             74.0     0.7300
# 13     13      2.0     5.2  -0.6   4.6             78.0     0.6788
# 14     14      2.0     5.6  -0.8   4.8             70.0     0.7110
# 15     15      2.0     6.0  -1.0   5.0             71.0     0.6861
# 16     16      2.0     6.4  -1.2   5.2             70.0     0.6871
# 17     17      2.0     6.8  -1.4   5.4             74.0     0.7068
# 18     18      2.0     7.2  -1.6   5.6             79.0     0.7054
# 19     19      2.0     7.6  -1.8   5.8             67.0     0.6981
#
#     training_score  test_score
# 0              NaN         NaN
# 1           0.7010      0.7914
# 2           0.7308      0.6783
# 3           0.7159      0.7367
# 4           0.7010      0.7914
# 5           0.7211      0.7183
# 6           0.7057      0.7733
# 7           0.7308      0.6783
# 8           0.7406      0.6350
# 9           0.7057      0.7733
# 10          0.7308      0.6783
# 11          0.7211      0.7183
# 12          0.7599      0.5600
# 13          0.7012      0.8533
# 14          0.7308      0.6783
# 15          0.7010      0.7914
# 16          0.7010      0.7914
# 17          0.7308      0.6783
# 18          0.7357      0.6567
# 19          0.7108      0.7550

# %%
dfpos2Full = pd.concat([dfpos2, dfpos2_2], axis=1)

# %%
dfpos2Full.head()
# Out:
#    Directory                                   Nonzero    Size    Ratio  \
# 0  01_vcenter_2.0_vrange_+0.4                      61.0   204.0  0.2990
# 1  02_vcenter_2.0_vrange_+0.8                      55.0   204.0  0.2696
# 2  03_vcenter_2.0_vrange_+1.2                      58.0   204.0  0.2843
# 3  04_vcenter_2.0_vrange_+1.6                      61.0   204.0  0.2990
# 4  05_vcenter_2.0_vrange_+2.0                      57.0   204.0  0.2794
#
#    index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 0      0      2.0     0.0   NaN   NaN              NaN        NaN
# 1      1      2.0     0.4   1.8   2.2             78.0     0.6787
# 2      2      2.0     0.8   1.6   2.4             78.0     0.7026
# 3      3      2.0     1.2   1.4   2.6             79.0     0.6896
# 4      4      2.0     1.6   1.2   2.8             72.0     0.6850
#
#    training_score  test_score
# 0             NaN         NaN
# 1          0.7010      0.7914
# 2          0.7308      0.6783
# 3          0.7159      0.7367
# 4          0.7010      0.7914

# %%
dfpos2Full.drop(0, axis=0, inplace=True)

# %%
dfpos2Full.head(1)
# Out:
#    Directory                                   Nonzero    Size    Ratio  \
# 1  02_vcenter_2.0_vrange_+0.8                      55.0   204.0  0.2696
#
#    index  vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# 1      1      2.0     0.4   1.8   2.2             78.0     0.6787
#
#    training_score  test_score
# 1           0.701      0.7914

# %%
dfpos2Full.columns
# Out:
# Index(['Directory                                ', ' Nonzero ', ' Size ',
#        ' Ratio', 'index', 'vcenter', 'vrange', 'vmin', 'vmax',
#        'num_of_features', 'a_fitness', 'training_score', 'test_score'],
#       dtype='object')

# %%
newcols = []
for col in dfpos2Full.columns:
    newcols.append(col.strip())
dfpos2Full.columns = newcols

# %%
dfpos2Full.columns
# Out:
# Index(['Directory', 'Nonzero', 'Size', 'Ratio', 'index', 'vcenter', 'vrange',
#        'vmin', 'vmax', 'num_of_features', 'a_fitness', 'training_score',
#        'test_score'],
#       dtype='object')

# %%
plt.scatter(dfpos2Full['Ratio'], dfpos2Full['test_score'])

# %%
dfpos2Full['Ratio'].corr(dfpos2Full['test_score'])
# Out:
# -0.4035769313003445

# %%
plt.scatter(dfpos2Full['Ratio'], dfpos2Full['training_score'])

# %%
dfpos2Full['Ratio'].corr(dfpos2Full['training_score'])
# Out:
# 0.39297060484484286

# %%
dfpos2subset = dfpos2Full[(dfpos2Full['vmax']+dfpos2Full['vmin']) / 2 > 0.0]

# %%
dfpos2subset
# Out:
#                                     Directory  Nonzero   Size   Ratio  index  \
# 1   02_vcenter_2.0_vrange_+0.8                    55.0  204.0  0.2696      1
# 2   03_vcenter_2.0_vrange_+1.2                    58.0  204.0  0.2843      2
# 3   04_vcenter_2.0_vrange_+1.6                    61.0  204.0  0.2990      3
# 4   05_vcenter_2.0_vrange_+2.0                    57.0  204.0  0.2794      4
# 5   06_vcenter_2.0_vrange_+2.4                    60.0  204.0  0.2941      5
# 6   07_vcenter_2.0_vrange_+2.8                    55.0  204.0  0.2696      6
# 7   08_vcenter_2.0_vrange_+3.2                    53.0  204.0  0.2598      7
# 8   09_vcenter_2.0_vrange_+3.6                    60.0  204.0  0.2941      8
# 9   10_vcenter_2.0_vrange_+4.0                    55.0  204.0  0.2696      9
# 10  11_vcenter_2.0_vrange_+4.4                    57.0  204.0  0.2794     10
# 11  12_vcenter_2.0_vrange_+4.8                    49.0  204.0  0.2402     11
# 12  13_vcenter_2.0_vrange_+5.2                    64.0  204.0  0.3137     12
# 13  14_vcenter_2.0_vrange_+5.6                    55.0  204.0  0.2696     13
# 14  15_vcenter_2.0_vrange_+6.0                    61.0  204.0  0.2990     14
# 15  16_vcenter_2.0_vrange_+6.4                    61.0  204.0  0.2990     15
# 16  17_vcenter_2.0_vrange_+6.8                    55.0  204.0  0.2696     16
# 17  18_vcenter_2.0_vrange_+7.2                    54.0  204.0  0.2647     17
# 18  19_vcenter_2.0_vrange_+7.6                    59.0  204.0  0.2892     18
# 19                                        NaN      NaN    NaN     NaN     19
#
#     vcenter  vrange  vmin  vmax  num_of_features  a_fitness  training_score  \
# 1       2.0     0.4   1.8   2.2             78.0     0.6787          0.7010
# 2       2.0     0.8   1.6   2.4             78.0     0.7026          0.7308
# 3       2.0     1.2   1.4   2.6             79.0     0.6896          0.7159
# 4       2.0     1.6   1.2   2.8             72.0     0.6850          0.7010
# 5       2.0     2.0   1.0   3.0             80.0     0.6926          0.7211
# 6       2.0     2.4   0.8   3.2             79.0     0.6814          0.7057
# 7       2.0     2.8   0.6   3.4             74.0     0.7068          0.7308
# 8       2.0     3.2   0.4   3.6             79.0     0.7093          0.7406
# 9       2.0     3.6   0.2   3.8             78.0     0.6825          0.7057
# 10      2.0     4.0   0.0   4.0             72.0     0.7089          0.7308
# 11      2.0     4.4  -0.2   4.2             79.0     0.6937          0.7211
# 12      2.0     4.8  -0.4   4.4             74.0     0.7300          0.7599
# 13      2.0     5.2  -0.6   4.6             78.0     0.6788          0.7012
# 14      2.0     5.6  -0.8   4.8             70.0     0.7110          0.7308
# 15      2.0     6.0  -1.0   5.0             71.0     0.6861          0.7010
# 16      2.0     6.4  -1.2   5.2             70.0     0.6871          0.7010
# 17      2.0     6.8  -1.4   5.4             74.0     0.7068          0.7308
# 18      2.0     7.2  -1.6   5.6             79.0     0.7054          0.7357
# 19      2.0     7.6  -1.8   5.8             67.0     0.6981          0.7108
#
#     test_score
# 1       0.7914
# 2       0.6783
# 3       0.7367
# 4       0.7914
# 5       0.7183
# 6       0.7733
# 7       0.6783
# 8       0.6350
# 9       0.7733
# 10      0.6783
# 11      0.7183
# 12      0.5600
# 13      0.8533
# 14      0.6783
# 15      0.7914
# 16      0.7914
# 17      0.6783
# 18      0.6567
# 19      0.7550

# %%
plt.scatter(dfpos2Full['test_score'], dfpos2Full['training_score'])

# %%
dfpos2Full['test_score'].corr(dfpos2Full['training_score'])
# Out:
# -0.9812230382202567
