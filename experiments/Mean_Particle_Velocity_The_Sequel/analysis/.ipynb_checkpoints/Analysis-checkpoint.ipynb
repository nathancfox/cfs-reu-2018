# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df00 = pd.read_csv('../00_report_velocities/particle_velocities.csv', header=None)
print(df00.shape)
df00.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0  0.226316  0.184211  0.200000  0.236842  0.173684  0.131579  0.252632
# 1  0.836842  0.789474  0.836842  0.831579  0.873684  0.773684  0.863158
# 2  0.805263  0.778947  0.789474  0.784211  0.815789  0.731579  0.794737
# 3  0.689474  0.584211  0.673684  0.657895  0.657895  0.521053  0.657895
# 4  0.500000  0.394737  0.363158  0.452632  0.368421  0.410526  0.394737
#
#          7         8         9     ...           90        91        92  \
# 0  0.178947  0.178947  0.221053    ...     0.236842  0.200000  0.173684
# 1  0.842105  0.857895  0.873684    ...     0.836842  0.847368  0.826316
# 2  0.705263  0.763158  0.789474    ...     0.763158  0.768421  0.773684
# 3  0.610526  0.552632  0.668421    ...     0.642105  0.605263  0.610526
# 4  0.373684  0.410526  0.400000    ...     0.378947  0.426316  0.363158
#
#          93        94        95        96        97        98        99
# 0  0.205263  0.184211  0.221053  0.215789  0.205263  0.221053  0.231579
# 1  0.857895  0.847368  0.831579  0.852632  0.863158  0.878947  0.810526
# 2  0.794737  0.800000  0.768421  0.742105  0.815789  0.821053  0.757895
# 3  0.621053  0.663158  0.610526  0.526316  0.552632  0.600000  0.615789
# 4  0.378947  0.363158  0.236842  0.194737  0.463158  0.447368  0.473684
#
# [5 rows x 100 columns]

# %%
df01 = pd.read_csv('../01_report_velocities/particle_velocities.csv', header=None)
print(df01.shape)
df01.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0  0.173684  0.215789  0.178947  0.231579  0.168421  0.257895  0.147368
# 1  0.821053  0.852632  0.868421  0.842105  0.815789  0.847368  0.831579
# 2  0.778947  0.810526  0.794737  0.826316  0.742105  0.794737  0.768421
# 3  0.605263  0.673684  0.636842  0.668421  0.589474  0.605263  0.631579
# 4  0.389474  0.542105  0.431579  0.442105  0.331579  0.326316  0.357895
#
#          7         8         9     ...           90        91        92  \
# 0  0.210526  0.221053  0.200000    ...     0.221053  0.157895  0.184211
# 1  0.836842  0.831579  0.826316    ...     0.873684  0.894737  0.873684
# 2  0.747368  0.805263  0.794737    ...     0.800000  0.821053  0.763158
# 3  0.657895  0.552632  0.684211    ...     0.605263  0.684211  0.600000
# 4  0.368421  0.384211  0.494737    ...     0.394737  0.468421  0.336842
#
#          93        94        95        96        97        98        99
# 0  0.173684  0.173684  0.184211  0.200000  0.189474  0.200000  0.189474
# 1  0.863158  0.805263  0.857895  0.831579  0.800000  0.584211  0.831579
# 2  0.800000  0.715789  0.789474  0.742105  0.763158  0.684211  0.789474
# 3  0.563158  0.563158  0.610526  0.521053  0.631579  0.552632  0.610526
# 4  0.300000  0.373684  0.378947  0.368421  0.363158  0.310526  0.373684
#
# [5 rows x 100 columns]

# %%
df02 = pd.read_csv('../02_report_velocities/particle_velocities.csv', header=None)
print(df02.shape)
df02.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0  0.242105  0.189474  0.152632  0.178947  0.205263  0.173684  0.168421
# 1  0.842105  0.794737  0.815789  0.815789  0.826316  0.826316  0.831579
# 2  0.789474  0.789474  0.800000  0.815789  0.821053  0.836842  0.773684
# 3  0.626316  0.715789  0.605263  0.663158  0.557895  0.631579  0.273684
# 4  0.489474  0.515789  0.415789  0.531579  0.415789  0.331579  0.336842
#
#          7         8         9     ...           90        91        92  \
# 0  0.236842  0.200000  0.236842    ...     0.200000  0.221053  0.242105
# 1  0.831579  0.847368  0.863158    ...     0.810526  0.794737  0.805263
# 2  0.778947  0.768421  0.800000    ...     0.768421  0.778947  0.784211
# 3  0.557895  0.652632  0.494737    ...     0.526316  0.631579  0.600000
# 4  0.410526  0.431579  0.373684    ...     0.415789  0.347368  0.473684
#
#          93        94        95        96        97        98        99
# 0  0.221053  0.184211  0.152632  0.226316  0.221053  0.200000  0.178947
# 1  0.810526  0.805263  0.778947  0.863158  0.842105  0.847368  0.842105
# 2  0.778947  0.831579  0.789474  0.789474  0.768421  0.731579  0.763158
# 3  0.610526  0.684211  0.621053  0.657895  0.605263  0.605263  0.578947
# 4  0.315789  0.410526  0.431579  0.247368  0.326316  0.373684  0.336842
#
# [5 rows x 100 columns]

# %%
timesteps = df00.shape[0]
for i in range(timesteps):
    plt.plot(df00.index[:timesteps], df00.iloc[:timesteps, :])
plt.gcf().set_size_inches(15, 10)
plt.ylim(0.0, 1.0)
plt.show()

# %%
timesteps = df00.shape[0]
for i in range(timesteps):
    plt.plot(df00.index[:timesteps], df00.iloc[:timesteps, :3])
plt.gcf().set_size_inches(15, 10)
plt.ylim(0.0, 1.0)
plt.show()

# %%
timesteps = df00.shape[0]
for i in range(timesteps):
    plt.plot(df00.index[:timesteps], df00.iloc[:timesteps, :1], '-v')
plt.gcf().set_size_inches(15, 10)
plt.ylim(0.0, 1.0)
plt.show()
