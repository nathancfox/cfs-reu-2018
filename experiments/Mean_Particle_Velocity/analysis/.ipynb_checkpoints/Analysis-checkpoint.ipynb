# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df00 = pd.read_csv('../00_report_velocities/particle_velocities.csv', header = None)
print(df00.shape)
df00.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0 -1.862029 -1.895721 -2.058265 -1.978806 -1.820415 -2.013322 -1.860832
# 1 -2.141959 -2.241638 -2.306853 -2.124775 -2.238976 -2.260845 -2.289453
# 2 -2.363146 -2.418635 -2.294827 -2.387694 -2.462988 -2.483454 -2.453614
# 3 -2.621778 -2.352257 -2.325859 -2.327576 -2.416889 -2.297829 -2.226975
# 4 -2.634044 -2.352092 -1.420565 -1.574379 -2.431916 -1.432604 -1.569217
#
#          7         8         9     ...           90        91        92  \
# 0 -1.711697 -1.855442 -1.979478    ...    -1.913528 -1.967569 -1.832303
# 1 -2.404390 -2.318415 -2.311361    ...    -2.100967 -2.442160 -2.263526
# 2 -2.536458 -2.582266 -2.562773    ...    -2.389922 -2.706128 -2.397024
# 3 -2.327535 -2.275472 -2.274939    ...    -2.747144 -2.730864 -2.643494
# 4 -1.419220 -2.397552 -1.400737    ...    -1.322129 -1.406597 -1.201826
#
#          93        94        95        96        97        98        99
# ...

# %%
df01 = pd.read_csv('../01_report_velocities/particle_velocities.csv', header = None)
print(df01.shape)
df01.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0 -2.032127 -1.875404 -1.961456 -1.886746 -1.927260 -1.726050 -1.803376
# 1 -1.971379 -2.226981 -2.035649 -1.938371 -2.456999 -2.089099 -2.266424
# 2 -2.053749 -2.274262 -2.280042 -2.110048 -2.519925 -2.368037 -2.435795
# 3 -2.522571 -2.188194 -2.149192 -2.015802 -1.990909 -1.998562 -2.133689
# 4 -1.403850 -1.195482 -1.214218 -2.258985 -1.430876 -1.543222 -1.396856
#
#          7         8         9     ...           90        91        92  \
# 0 -1.794055 -1.864312 -1.711801    ...    -2.040833 -1.936614 -1.913950
# 1 -2.296985 -2.115962 -2.099854    ...    -2.232756 -2.396574 -2.403101
# 2 -2.365300 -2.254703 -2.373568    ...    -2.231864 -2.688986 -2.501455
# 3 -1.968046 -1.940413 -2.079781    ...    -2.560005 -2.576345 -2.522600
# 4 -1.417155 -1.535650 -1.471093    ...    -1.558710 -1.412494 -2.327123
#
#          93        94        95        96        97        98        99
# ...

# %%
df02 = pd.read_csv('../02_report_velocities/particle_velocities.csv', header = None)
print(df02.shape)
df02.head()
# Out:
# (150, 100)
#          0         1         2         3         4         5         6   \
# 0 -1.813432 -1.850383 -1.812709 -1.813529 -1.895441 -1.882808 -2.003873
# 1 -1.744151 -2.122091 -2.167483 -2.112219 -2.123528 -2.254005 -2.196640
# 2 -1.836753 -2.554160 -2.243082 -2.179797 -2.181191 -2.439725 -2.195649
# 3 -2.422203 -2.274043 -2.021490 -2.233482 -2.088062 -2.174061 -2.095843
# 4 -1.219844 -1.254234 -0.993622 -2.071102 -1.063462 -1.963167 -2.053108
#
#          7         8         9     ...           90        91        92  \
# 0 -1.834063 -1.833461 -1.780985    ...    -1.897475 -1.917513 -1.836885
# 1 -2.320191 -2.161288 -2.096017    ...    -2.392585 -2.385508 -2.283469
# 2 -2.191167 -2.057687 -2.313246    ...    -2.546933 -2.484422 -2.315784
# 3 -2.098316 -2.194459 -2.055731    ...    -2.423133 -2.441302 -2.267405
# 4 -1.948142 -1.185554 -1.877650    ...    -2.231606 -1.385577 -2.083079
#
#          93        94        95        96        97        98        99
# ...

# %%
steps = df00.shape[0]
for i in range(df00.shape[1]):
    plt.plot([i for i in range(steps)], df00.iloc[:steps, :], '-x')
plt.gcf().set_size_inches(15, 10)
plt.title('Mean Velocity for 100 Particles')
plt.xlabel('Time')
plt.ylabel('Mean of Values in Velocity Vector')
plt.savefig('../../lab_notebooks/cfs_notebook_files/Mean_Particle_Velocity_PLOT_Full.svg')
#plt.show()

# %%
steps = 8 # df00.shape[0]
for i in range(df00.shape[1]):
    plt.plot([i for i in range(steps)], df00.iloc[:steps, :], '-x')
plt.gcf().set_size_inches(15, 10)
plt.title('Mean Velocity for 100 Particles - Zoomed In')
plt.xlabel('Time')
plt.ylabel('Mean of Values in Velocity Vector')
plt.savefig('../../lab_notebooks/cfs_notebook_files/Mean_Particle_Velocity_PLOT_t_7.svg')
# plt.show()
