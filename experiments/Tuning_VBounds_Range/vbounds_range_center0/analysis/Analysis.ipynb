# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use('ggplot')

# %%
df = pd.read_csv('raw_data.csv', index_col=0)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 0          0.0     0.0   NaN   NaN              NaN        NaN
# 1          0.0     0.4  -0.2   0.2             53.0     0.7367
# 2          0.0     0.8  -0.4   0.4             55.0     0.7067
# 3          0.0     1.2  -0.6   0.6             58.0     0.7035
# 4          0.0     1.6  -0.8   0.8             57.0     0.7087
#
#        training_score  test_score
# index
# 0                 NaN         NaN
# 1              0.7406      0.6150
# 2              0.7057      0.7733
# 3              0.7057      0.7733
# 4              0.7108      0.7550

# %%
df.tail()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 15         0.0     6.0  -3.0   3.0             25.0     0.7544
# 16         0.0     6.4  -3.2   3.2             28.0     0.7746
# 17         0.0     6.8  -3.4   3.4             25.0     0.7544
# 18         0.0     7.2  -3.6   3.6             32.0     0.7705
# 19         0.0     7.6  -3.8   3.8             29.0     0.7662
#
#        training_score  test_score
# index
# 15             0.7259      0.7000
# 16             0.7551      0.6350
# 17             0.7259      0.7000
# 18             0.7553      0.7000
# 19             0.7459      0.7183

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 1          0.0     0.4  -0.2   0.2             53.0     0.7367
# 2          0.0     0.8  -0.4   0.4             55.0     0.7067
# 3          0.0     1.2  -0.6   0.6             58.0     0.7035
# 4          0.0     1.6  -0.8   0.8             57.0     0.7087
# 5          0.0     2.0  -1.0   1.0             49.0     0.7249
#
#        training_score  test_score
# index
# 1              0.7406      0.6150
# 2              0.7057      0.7733
# 3              0.7057      0.7733
# 4              0.7108      0.7550
# 5              0.7206      0.7550

# %%
df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']].describe()
# Out:
#           vrange  num_of_features  a_fitness  training_score  test_score
# count  19.000000        19.000000  19.000000       19.000000   19.000000
# mean    4.000000        44.578947   0.735263        0.727732    0.725868
# std     2.250926        11.781887   0.021050        0.015871    0.045564
# min     0.400000        25.000000   0.703500        0.705700    0.615000
# 25%     2.200000        33.500000   0.720800        0.718250    0.700000
# 50%     4.000000        49.000000   0.732700        0.725900    0.736700
# 75%     5.800000        54.500000   0.746650        0.740400    0.755000
# max     7.600000        58.000000   0.774600        0.755300    0.773300

# %%
sns.pairplot(df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']])
plt.savefig('../../../lab_notebooks/cfs_notebook_files/Tuning_VBounds_Range_vcenter_0.0_pairplot.svg')

# %%
df.corr(method='pearson')
# Out:
#                  vcenter    vrange      vmin      vmax  num_of_features  \
# vcenter              NaN       NaN       NaN       NaN              NaN
# vrange               NaN  1.000000 -1.000000  1.000000        -0.881510
# vmin                 NaN -1.000000  1.000000 -1.000000         0.881510
# vmax                 NaN  1.000000 -1.000000  1.000000        -0.881510
# num_of_features      NaN -0.881510  0.881510 -0.881510         1.000000
# a_fitness            NaN  0.824602 -0.824602  0.824602        -0.834986
# training_score       NaN  0.507270 -0.507270  0.507270        -0.408674
# test_score           NaN -0.169049  0.169049 -0.169049         0.340556
#
#                  a_fitness  training_score  test_score
# vcenter                NaN             NaN         NaN
# vrange            0.824602        0.507270   -0.169049
# vmin             -0.824602       -0.507270    0.169049
# vmax              0.824602        0.507270   -0.169049
# num_of_features  -0.834986       -0.408674    0.340556
# a_fitness         1.000000        0.843457   -0.638123
# training_score    0.843457        1.000000   -0.725669
# test_score       -0.638123       -0.725669    1.000000
