# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use('ggplot')

# %%
df = pd.read_csv('raw_data.csv', index_col=0)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 0          4.0     0.0   NaN   NaN              NaN        NaN
# 1          4.0     0.4   3.8   4.2             71.0     0.7177
# 2          4.0     0.8   3.6   4.4             74.0     0.6908
# 3          4.0     1.2   3.4   4.6             79.0     0.7054
# 4          4.0     1.6   3.2   4.8             78.0     0.6986
#
#        training_score  test_score
# index
# 0                 NaN         NaN
# 1              0.7406      0.6350
# 2              0.7108      0.7550
# 3              0.7357      0.6567
# 4              0.7259      0.7000

# %%
df.tail()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 15         4.0     6.0   1.0   7.0             68.0     0.7053
# 16         4.0     6.4   0.8   7.2             74.0     0.7029
# 17         4.0     6.8   0.6   7.4             72.0     0.6888
# 18         4.0     7.2   0.4   7.6             74.0     0.6908
# 19         4.0     7.6   0.2   7.8             72.0     0.7050
#
#        training_score  test_score
# index
# 15             0.7211      0.7183
# 16             0.7259      0.7000
# 17             0.7057      0.7733
# 18             0.7108      0.7550
# 19             0.7259      0.7000

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 1          4.0     0.4   3.8   4.2             71.0     0.7177
# 2          4.0     0.8   3.6   4.4             74.0     0.6908
# 3          4.0     1.2   3.4   4.6             79.0     0.7054
# 4          4.0     1.6   3.2   4.8             78.0     0.6986
# 5          4.0     2.0   3.0   5.0             72.0     0.7089
#
#        training_score  test_score
# index
# 1              0.7406      0.6350
# 2              0.7108      0.7550
# 3              0.7357      0.6567
# 4              0.7259      0.7000
# 5              0.7308      0.6783

# %%
df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']].describe()
# Out:
#           vrange  num_of_features  a_fitness  training_score  test_score
# count  19.000000        19.000000  19.000000       19.000000   19.000000
# mean    4.000000        75.473684   0.698716        0.722679    0.711368
# std     2.250926         4.141503   0.010060        0.013183    0.050228
# min     0.400000        68.000000   0.682900        0.701000    0.613300
# 25%     2.200000        72.000000   0.690800        0.710800    0.678300
# 50%     4.000000        74.000000   0.699700        0.725900    0.700000
# 75%     5.800000        78.000000   0.705150        0.730800    0.755000
# max     7.600000        86.000000   0.717700        0.745500    0.791400

# %%
sns.pairplot(df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']])

# %%
df.corr(method='pearson')
# Out:
#                  vcenter    vrange      vmin      vmax  num_of_features  \
# vcenter              NaN       NaN       NaN       NaN              NaN
# vrange               NaN  1.000000 -1.000000  1.000000        -0.102503
# vmin                 NaN -1.000000  1.000000 -1.000000         0.102503
# vmax                 NaN  1.000000 -1.000000  1.000000        -0.102503
# num_of_features      NaN -0.102503  0.102503 -0.102503         1.000000
# a_fitness            NaN -0.263606  0.263606 -0.263606        -0.106069
# training_score       NaN -0.295729  0.295729 -0.295729         0.313187
# test_score           NaN  0.342140 -0.342140  0.342140        -0.200546
#
#                  a_fitness  training_score  test_score
# vcenter                NaN             NaN         NaN
# vrange           -0.263606       -0.295729    0.342140
# vmin              0.263606        0.295729   -0.342140
# vmax             -0.263606       -0.295729    0.342140
# num_of_features  -0.106069        0.313187   -0.200546
# a_fitness         1.000000        0.911107   -0.939274
# training_score    0.911107        1.000000   -0.980044
# test_score       -0.939274       -0.980044    1.000000
