# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use('ggplot')

# %%
df = pd.read_csv('raw_data.csv', index_col=0)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 0          2.0     0.0   NaN   NaN              NaN        NaN
# 1          2.0     0.4   1.8   2.2             78.0     0.6787
# 2          2.0     0.8   1.6   2.4             78.0     0.7026
# 3          2.0     1.2   1.4   2.6             79.0     0.6896
# 4          2.0     1.6   1.2   2.8             72.0     0.6850
#
#        training_score  test_score
# index
# 0                 NaN         NaN
# 1              0.7010      0.7914
# 2              0.7308      0.6783
# 3              0.7159      0.7367
# 4              0.7010      0.7914

# %%
df.tail()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 15         2.0     6.0  -1.0   5.0             71.0     0.6861
# 16         2.0     6.4  -1.2   5.2             70.0     0.6871
# 17         2.0     6.8  -1.4   5.4             74.0     0.7068
# 18         2.0     7.2  -1.6   5.6             79.0     0.7054
# 19         2.0     7.6  -1.8   5.8             67.0     0.6981
#
#        training_score  test_score
# index
# 15             0.7010      0.7914
# 16             0.7010      0.7914
# 17             0.7308      0.6783
# 18             0.7357      0.6567
# 19             0.7108      0.7550

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
#        vcenter  vrange  vmin  vmax  num_of_features  a_fitness  \
# index
# 1          2.0     0.4   1.8   2.2             78.0     0.6787
# 2          2.0     0.8   1.6   2.4             78.0     0.7026
# 3          2.0     1.2   1.4   2.6             79.0     0.6896
# 4          2.0     1.6   1.2   2.8             72.0     0.6850
# 5          2.0     2.0   1.0   3.0             80.0     0.6926
#
#        training_score  test_score
# index
# 1              0.7010      0.7914
# 2              0.7308      0.6783
# 3              0.7159      0.7367
# 4              0.7010      0.7914
# 5              0.7211      0.7183

# %%
df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']].describe()
# Out:
#           vrange  num_of_features  a_fitness  training_score  test_score
# count  19.000000        19.000000  19.000000       19.000000   19.000000
# mean    4.000000        75.315789   0.696547        0.719774    0.723000
# std     2.250926         4.014593   0.013814        0.016924    0.070988
# min     0.400000        67.000000   0.678700        0.701000    0.560000
# 25%     2.200000        72.000000   0.685550        0.703450    0.678300
# 50%     4.000000        78.000000   0.693700        0.721100    0.718300
# 75%     5.800000        79.000000   0.706800        0.730800    0.782350
# max     7.600000        80.000000   0.730000        0.759900    0.853300

# %%
sns.pairplot(df.loc[:, ['vrange', 'num_of_features', 'a_fitness', 'training_score', 'test_score']])

# %%
df.corr(method='pearson')
# Out:
#                  vcenter    vrange      vmin      vmax  num_of_features  \
# vcenter              NaN       NaN       NaN       NaN              NaN
# vrange               NaN  1.000000 -1.000000  1.000000        -0.531176
# vmin                 NaN -1.000000  1.000000 -1.000000         0.531176
# vmax                 NaN  1.000000 -1.000000  1.000000        -0.531176
# num_of_features      NaN -0.531176  0.531176 -0.531176         1.000000
# a_fitness            NaN  0.274795 -0.274795  0.274795        -0.216268
# training_score       NaN  0.114804 -0.114804  0.114804         0.092120
# test_score           NaN -0.083958  0.083958 -0.083958        -0.050178
#
#                  a_fitness  training_score  test_score
# vcenter                NaN             NaN         NaN
# vrange            0.274795        0.114804   -0.083958
# vmin             -0.274795       -0.114804    0.083958
# vmax              0.274795        0.114804   -0.083958
# num_of_features  -0.216268        0.092120   -0.050178
# a_fitness         1.000000        0.952256   -0.946866
# training_score    0.952256        1.000000   -0.981223
# test_score       -0.946866       -0.981223    1.000000
