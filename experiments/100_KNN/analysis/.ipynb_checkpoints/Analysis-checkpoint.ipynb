# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
max = 0
with open('reported_kinases.csv', 'r') as f:
    for line in f:
        l = len(line.split(','))
        if l > max:
            max = l

# %%
max
# Out:
# 36

# %%
kin_df = pd.read_csv('reported_kinases.csv', header=None, names=range(36))

# %%
kin_df
# Out:
#           0         1         2         3         4        5        6   \
# 0      AURKC      CDK4      CHUK      EGFR     ERBB4      FES    GSK3A
# 1        AXL       BLK      CDK2      EGFR     ERBB2     GRK6    MKNK2
# 2       AKT2      CDK1    DYRK1B      EGFR     ERBB2    MKNK1    PDPK1
# 3       AKT1    CAMK1D    CAMK2A      CDK1   CSNK1A1     EGFR    ERBB4
# 4      AURKA       BMX      CDK1     CHEK2   CSNK1A1  CSNK1G2     DDR2
# 5       ABL1      CDK1      CDK6      CLK3      EGFR    EPHB3      FRK
# 6   CDC42BPA      CHUK     ERBB4     FGFR4     GSK3A      ITK     JAK2
# 7       AKT3       ALK    CAMK1D    CAMK2D      CDK2     CHUK  CSNK1A1
# 8      AURKA      CHUK     CSF1R   CSNK1A1   CSNK1G3     EGFR    ERBB2
# 9      BRSK2       CSK      EGFR     ERBB4       FGR      LYN    MARK2
# 10      ABL1      CHUK      EGFR     EPHA4     ERBB4    FGFR4      FYN
# 11       ALK     BRSK2      CDK5   CSNK1G1    DYRK1A     EGFR      FER
# 12     BRSK2     CAMK4   CSNK1G3      EGFR     ERBB4      FGR      FYN
# 13       ALK       BLK     CAMK4  CDC42BPA      CDK3    CHEK2  CSNK1A1
# 14       BTK   CSNK1A1     DAPK1      DDR2      EGFR    ERBB4    IKBKE
# 15      ABL2       ALK     AURKA     AURKB     BRSK1    BRSK2   CAMK2D
# 16      ABL1       BTK      CDK5     CHEK1   CSNK1A1  CSNK1G3     EGFR
# 17      ABL2     AURKA       BTK      CDK2      CHUK    CSF1R     DDR2
# 18       BMX      CHUK   CSNK1G3      EGFR     ERBB4    GSK3A    IRAK4
# 19     BRSK2      CHUK      EGFR     ROCK1   RPS6KA1     SIK2      TTK
# 20     AURKA      CDK2   CSNK1G3     DYRK2      EGFR    IKBKB    IKBKE
# 21      ABL1      CHUK    DYRK1B      EGFR     EPHB2     FLT3      LTK
# 22       ALK     AURKA     AURKC       AXL      CDK5  CSNK1G2     DDR2
# 23      BRAF  CDC42BPB      CHUK     DYRK2      EGFR    EPHA2      FES
# 24       BMX     BRSK2      CDK2   CSNK1A1     GSK3A    INSRR     JAK3
# 25      ABL2      AKT2       BTK    CAMK2D      CDK5  CSNK1G1     DDR2
# 26     AURKA      BRAF     BRSK2  CDC42BPB     CSF1R  CSNK1A1     EGFR
# 27      ABL2       AXL      CDK1      CDK3      CHUK  CSNK1A1   DYRK1B
# 28       AXL      CHUK      EGFR     EPHA2       KIT    MKNK2     PAK6
# 29       BMX    CAMK2D      EGFR     ERBB4       FYN    GSK3A     JAK2
# ..       ...       ...       ...       ...       ...      ...      ...
# 70     CHEK2      CHUK     DCLK2      EGFR       LTK     NEK1     NEK9
# 71      BRAF      CDK2      CDK3     CHEK1     CHEK2     CHUK     EGFR
# 72    DYRK1A      EGFR     IKBKB       LTK    MAPK13    MAPK9    MARK2
# 73       ALK       BMX    CAMK1D     CHEK2      CLK2     EGFR    EPHB4
# 74    CAMK2D      CHUK      EGFR      MELK     ROCK2     ROS1     SIK2
# 75       BMX     BRSK2      CHUK      EGFR      MELK    PHKG1   PRKAA2
# 76       AXL      CHUK      EGFR     IKBKE      JAK2      LTK     PASK
# 77       ALK       BMX      CDK4      CHUK      EGFR      FER      FYN
# 78      CDK2      CDK6      CLK3    DYRK1B      EGFR    EPHB2      FES
# 79      ABL2       ALK      CDK1      CHUK   CSNK1G1     EGFR    EPHA3
# 80       AXL     BRSK1   CSNK1A1      EGFR     ERBB4     JAK2      KIT
# 81      AKT3     AURKB      CDK1      EGFR       KIT      LCK    LRRK2
# 82       AXL    CAMK2D     CAMK4      CDK6     CHEK1  CSNK1A1     EGFR
# 83     AURKC      CDK2      CDK5     DAPK1      DDR2     EGFR      FER
# 84    CAMK2D      CDK1      CDK2     DAPK1    DYRK1B     EGFR    ERBB4
# 85       AXL       BMX      CHUK   CSNK1G3    DYRK1A     EGFR      HCK
# 86      ABL1      AKT3       BMX       CSK   CSNK1G2     EGFR      FGR
# 87      BRAF       CSK   CSNK1G2     DCLK2      EGFR      LTK    MARK3
# 88     AURKA     BRSK1      CDK1      CDK4     CSF1R      CSK   DYRK1A
# 89      AKT3     BRSK1      CHUK    DYRK1B      EGFR      ITK    MARK2
# 90       AXL    CAMK1D      CHUK       CSK   CSNK1A1     DDR2     EGFR
# 91     AURKA       BLK      CHUK   CSNK1A1   CSNK1G3    ERBB4      FER
# 92       BMX      CHUK      EGFR       FER     FGFR3    FGFR4    GSK3A
# 93  CDC42BPA  CDC42BPB      CDK3      CHUK      EGFR    ERBB2    IKBKE
# 94       ALK      BRAF    CAMK1D      CHUK     CSF1R     EGFR    EPHA2
# 95      ABL1     BRSK1     CSF1R       CSK      EGFR    IKBKE     JAK2
# 96      ABL2      AKT2      BRAF     CAMK4      CDK1    CSF1R  CSNK1G1
# 97      AKT2       AXL  CDC42BPB      CHUK     ERBB4    GSK3A    HIPK1
# 98      CDK1      CHUK      EGFR     FGFR4      GRK6     PLK1    ROCK2
# 99      AKT1       AXL     BRSK2       BTK  CDC42BPB     CLK3     EGFR
#
#         7         8        9  ...      26       27       28    29    30   31  \
# 0      KIT    MAP4K4   MAPK14 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 1    ROCK2      SIK1      TTK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 2    ROCK1   RPS6KA1     SGK2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 3   MAP2K1  MAPKAPK2    MARK3 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 4     EGFR     EPHA3    ERBB4 ...   ROCK1  RPS6KA3  RPS6KA5  SIK2  STK3  TEK
# 5    GSK3A       HCK    IRAK4 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 6      LTK     MAPK1   MAPK14 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 7     EGFR     ERBB4     FLT1 ...    TBK1      NaN      NaN   NaN   NaN  NaN
# 8    ERBB4     GSK3B    IKBKB ...     NaN      NaN      NaN   NaN   NaN  NaN
# 9      MET      PAK6    PHKG2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 10   GSK3A      JAK1   MAPK14 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 11     FGR       FRK     GRK6 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 12    JAK1     MKNK2    PRKG1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 13   DCLK2       FES     FLT1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 14     KIT  MAPKAPK2    NUAK1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 15    CDK2     DAPK1    DCLK2 ...    SGK3     STK3      TTK   NaN   NaN  NaN
# 16   EPHB4     IKBKE      KIT ...     NaN      NaN      NaN   NaN   NaN  NaN
# 17  DYRK1B     DYRK2     EGFR ...     NaN      NaN      NaN   NaN   NaN  NaN
# 18     LTK      NEK9    NUAK1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 19     NaN       NaN      NaN ...     NaN      NaN      NaN   NaN   NaN  NaN
# 20    JAK2       LTK    MAPK3 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 21  MAP2K1    MAP4K2   MAPK11 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 22    EGFR     MAPK3    MAPK9 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 23   GSK3B    MAP2K1     MUSK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 24     KIT       LCK      LYN ...     NaN      NaN      NaN   NaN   NaN  NaN
# 25    EGFR     GSK3B   MAP4K4 ...    SGK3     SIK2     TNK2   NaN   NaN  NaN
# 26   EPHA2     ERBB4    GSK3B ...     NaN      NaN      NaN   NaN   NaN  NaN
# 27    EGFR     EPHA3      FRK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 28   PHKG2    PRKAA2     PTK6 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 29   LRRK2    MAPK11     MUSK ...     NaN      NaN      NaN   NaN   NaN  NaN
# ..     ...       ...      ... ...     ...      ...      ...   ...   ...  ...
# 70   PDPK1   RPS6KA1  RPS6KA5 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 71   IKBKE      JAK2     PASK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 72    MUSK    PRKAA2    PRKG2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 73    FLT3     IKBKE   MAPK11 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 74     TTK       NaN      NaN ...     NaN      NaN      NaN   NaN   NaN  NaN
# 75  PRKACA     PRKD1    ROCK1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 76   PDPK1     ROCK1     TBK1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 77   GSK3A     GSK3B    IKBKB ...     NaN      NaN      NaN   NaN   NaN  NaN
# 78     FGR     GSK3B    INSRR ...   STK10     TNK2    TSSK2   NaN   NaN  NaN
# 79   IKBKE      JAK2    LRRK2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 80  MAP4K4    MAPK11    PRKCB ...     NaN      NaN      NaN   NaN   NaN  NaN
# 81   MAPK1    MAPK14    MARK2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 82   ERBB4     GSK3B      LCK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 83     FRK       LTK    MAPK3 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 84   GSK3B     IRAK4      ITK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 85   IKBKE     ROCK1  RPS6KA3 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 86   GSK3B     INSRR      LTK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 87    MUSK     NTRK2     PAK6 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 88    EGFR     EPHA4    ERBB4 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 89   NTRK2     ROCK1     ROS1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 90   GSK3A       HCK    IKBKB ...     NaN      NaN      NaN   NaN   NaN  NaN
# 91   GSK3B       ITK      LTK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 92     LTK    MAPK13    MERTK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 93    JAK2       LTK   MAP2K1 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 94   ERBB2       FER      FES ...     NaN      NaN      NaN   NaN   NaN  NaN
# 95     LYN    MAPK13    MKNK2 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 96    DDR2      EGFR    EPHB4 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 97    JAK2       KIT   MAPK14 ...     NaN      NaN      NaN   NaN   NaN  NaN
# 98    SIK2      STK4      TTK ...     NaN      NaN      NaN   NaN   NaN  NaN
# 99   EPHA2     EPHB2    EPHB4 ...     NaN      NaN      NaN   NaN   NaN  NaN
#
#      32   33   34   35
# 0   NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN
# 4   TXK  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  NaN
# 23  NaN  NaN  NaN  NaN
# 24  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN
# 26  NaN  NaN  NaN  NaN
# 27  NaN  NaN  NaN  NaN
# 28  NaN  NaN  NaN  NaN
# 29  NaN  NaN  NaN  NaN
# ..  ...  ...  ...  ...
# 70  NaN  NaN  NaN  NaN
# 71  NaN  NaN  NaN  NaN
# 72  NaN  NaN  NaN  NaN
# 73  NaN  NaN  NaN  NaN
# 74  NaN  NaN  NaN  NaN
# 75  NaN  NaN  NaN  NaN
# 76  NaN  NaN  NaN  NaN
# 77  NaN  NaN  NaN  NaN
# 78  NaN  NaN  NaN  NaN
# 79  NaN  NaN  NaN  NaN
# 80  NaN  NaN  NaN  NaN
# 81  NaN  NaN  NaN  NaN
# 82  NaN  NaN  NaN  NaN
# 83  NaN  NaN  NaN  NaN
# 84  NaN  NaN  NaN  NaN
# 85  NaN  NaN  NaN  NaN
# 86  NaN  NaN  NaN  NaN
# 87  NaN  NaN  NaN  NaN
# 88  NaN  NaN  NaN  NaN
# 89  NaN  NaN  NaN  NaN
# 90  NaN  NaN  NaN  NaN
# 91  NaN  NaN  NaN  NaN
# 92  NaN  NaN  NaN  NaN
# 93  NaN  NaN  NaN  NaN
# 94  NaN  NaN  NaN  NaN
# 95  NaN  NaN  NaN  NaN
# 96  NaN  NaN  NaN  NaN
# 97  NaN  NaN  NaN  NaN
# 98  NaN  NaN  NaN  NaN
# 99  NaN  NaN  NaN  NaN
#
# [100 rows x 36 columns]

# %%
kin = []
with open('reported_kinases.csv', 'r') as f:
    for line in f:
        kin.append(line.strip().split(','))

# %%
kin
# Out:
# [['AURKC',
#   'CDK4',
#   'CHUK',
#   'EGFR',
#   'ERBB4',
#   'FES',
#   'GSK3A',
#   'KIT',
#   'MAP4K4',
#   'MAPK14',
#   'PASK',
#   'PRKX',
#   'RPS6KA2',
#   'SIK2',
#   'SRMS'],
#  ['AXL',
#   'BLK',
#   'CDK2',
#   'EGFR',
#   'ERBB2',
#   'GRK6',
#   'MKNK2',
#   'ROCK2',
#   'SIK1',
#   'TTK'],
#  ['AKT2',
#   'CDK1',
#   'DYRK1B',
#   'EGFR',
#   'ERBB2',
#   'MKNK1',
#   'PDPK1',
#   'ROCK1',
#   'RPS6KA1',
#   'SGK2',
#   'SIK2',
#   'STK4',
#   'TTK',
#   'YES1'],
#  ['AKT1',
#   'CAMK1D',
#   'CAMK2A',
#   'CDK1',
#   'CSNK1A1',
#   'EGFR',
#   'ERBB4',
#   'MAP2K1',
#   'MAPKAPK2',
#   'MARK3',
#   'MELK',
#   'MERTK',
#   'MINK1',
#   'PIK3CA',
#   'PRKG2',
#   'ROCK2',
#   'RPS6KA2',
#   'SGK3',
#   'SIK2',
#   'SRMS',
#   'TTK'],
#  ['AURKA',
#   'BMX',
#   'CDK1',
#   'CHEK2',
#   'CSNK1A1',
#   'CSNK1G2',
#   'DDR2',
#   'EGFR',
#   'EPHA3',
#   'ERBB4',
#   'FER',
#   'FGR',
#   'FLT3',
#   'FLT4',
#   'GSK3A',
#   'IRAK4',
#   'JAK2',
#   'LTK',
#   'MAPK12',
#   'MARK4',
#   'MKNK2',
#   'NTRK3',
#   'PAK6',
#   'PIK3CA',
#   'PRKG1',
#   'PRKX',
#   'ROCK1',
#   'RPS6KA3',
#   'RPS6KA5',
#   'SIK2',
#   'STK3',
#   'TEK',
#   'TXK'],
#  ['ABL1',
#   'CDK1',
#   'CDK6',
#   'CLK3',
#   'EGFR',
#   'EPHB3',
#   'FRK',
#   'GSK3A',
#   'HCK',
#   'IRAK4',
#   'JAK2',
#   'LRRK2',
#   'LTK',
#   'MUSK',
#   'PRKX',
#   'ROCK2',
#   'RPS6KA2',
#   'RPS6KA3'],
#  ['CDC42BPA',
#   'CHUK',
#   'ERBB4',
#   'FGFR4',
#   'GSK3A',
#   'ITK',
#   'JAK2',
#   'LTK',
#   'MAPK1',
#   'MAPK14',
#   'MUSK',
#   'PAK6',
#   'PHKG2',
#   'PRKG2',
#   'ROCK2',
#   'SGK1',
#   'SRMS',
#   'SYK'],
#  ['AKT3',
#   'ALK',
#   'CAMK1D',
#   'CAMK2D',
#   'CDK2',
#   'CHUK',
#   'CSNK1A1',
#   'EGFR',
#   'ERBB4',
#   'FLT1',
#   'GSK3A',
#   'JAK1',
#   'LRRK2',
#   'LTK',
#   'MAPK13',
#   'MUSK',
#   'NTRK2',
#   'PAK1',
#   'PIK3CA',
#   'PRKCB',
#   'PRKD1',
#   'ROCK1',
#   'ROS1',
#   'RPS6KA1',
#   'RPS6KA4',
#   'SRMS',
#   'TBK1'],
#  ['AURKA',
#   'CHUK',
#   'CSF1R',
#   'CSNK1A1',
#   'CSNK1G3',
#   'EGFR',
#   'ERBB2',
#   'ERBB4',
#   'GSK3B',
#   'IKBKB',
#   'LRRK2',
#   'MELK',
#   'MERTK',
#   'MST4',
#   'PAK1',
#   'ROCK1',
#   'SIK2',
#   'SRC',
#   'TTK'],
#  ['BRSK2',
#   'CSK',
#   'EGFR',
#   'ERBB4',
#   'FGR',
#   'LYN',
#   'MARK2',
#   'MET',
#   'PAK6',
#   'PHKG2',
#   'PRKG1',
#   'ROCK2',
#   'SGK3',
#   'SIK2',
#   'TTK',
#   'ZAP70'],
#  ['ABL1',
#   'CHUK',
#   'EGFR',
#   'EPHA4',
#   'ERBB4',
#   'FGFR4',
#   'FYN',
#   'GSK3A',
#   'JAK1',
#   'MAPK14',
#   'MAPK3',
#   'MARK4',
#   'MUSK',
#   'NTRK3',
#   'PAK2',
#   'PDPK1',
#   'PRKD2',
#   'PRKX',
#   'ROCK1',
#   'RPS6KA3',
#   'STK4'],
#  ['ALK',
#   'BRSK2',
#   'CDK5',
#   'CSNK1G1',
#   'DYRK1A',
#   'EGFR',
#   'FER',
#   'FGR',
#   'FRK',
#   'GRK6',
#   'JAK2',
#   'MARK4',
#   'MST1R',
#   'MUSK',
#   'NUAK1',
#   'PLK1',
#   'PRKX',
#   'PTK6',
#   'ROCK1',
#   'RPS6KA3'],
#  ['BRSK2',
#   'CAMK4',
#   'CSNK1G3',
#   'EGFR',
#   'ERBB4',
#   'FGR',
#   'FYN',
#   'JAK1',
#   'MKNK2',
#   'PRKG1',
#   'RPS6KA1',
#   'RPS6KA5',
#   'SRMS',
#   'TTK'],
#  ['ALK',
#   'BLK',
#   'CAMK4',
#   'CDC42BPA',
#   'CDK3',
#   'CHEK2',
#   'CSNK1A1',
#   'DCLK2',
#   'FES',
#   'FLT1',
#   'IKBKE',
#   'KIT',
#   'MAP4K4',
#   'MAPK11',
#   'MAPK9',
#   'MAPKAPK5',
#   'MARK4',
#   'MUSK',
#   'NTRK1',
#   'PLK1',
#   'PRKD2',
#   'PRKD3',
#   'ROCK1',
#   'SGK2',
#   'SRPK3'],
#  ['BTK',
#   'CSNK1A1',
#   'DAPK1',
#   'DDR2',
#   'EGFR',
#   'ERBB4',
#   'IKBKE',
#   'KIT',
#   'MAPKAPK2',
#   'NUAK1',
#   'PRKG1',
#   'ROCK1',
#   'RPS6KA3',
#   'SIK2',
#   'SRC',
#   'SRPK3',
#   'STK3'],
#  ['ABL2',
#   'ALK',
#   'AURKA',
#   'AURKB',
#   'BRSK1',
#   'BRSK2',
#   'CAMK2D',
#   'CDK2',
#   'DAPK1',
#   'DCLK2',
#   'EGFR',
#   'EPHA3',
#   'ERBB4',
#   'FGFR3',
#   'GSK3A',
#   'IRAK4',
#   'KIT',
#   'LRRK2',
#   'MUSK',
#   'NEK2',
#   'NTRK1',
#   'NUAK1',
#   'PAK2',
#   'PRKX',
#   'RPS6KA2',
#   'RPS6KA6',
#   'SGK3',
#   'STK3',
#   'TTK'],
#  ['ABL1',
#   'BTK',
#   'CDK5',
#   'CHEK1',
#   'CSNK1A1',
#   'CSNK1G3',
#   'EGFR',
#   'EPHB4',
#   'IKBKE',
#   'KIT',
#   'MAPK11',
#   'MAPKAPK5',
#   'NEK1',
#   'PRKCG',
#   'ROCK2',
#   'SIK2',
#   'SRPK1',
#   'STK3',
#   'STK4'],
#  ['ABL2',
#   'AURKA',
#   'BTK',
#   'CDK2',
#   'CHUK',
#   'CSF1R',
#   'DDR2',
#   'DYRK1B',
#   'DYRK2',
#   'EGFR',
#   'FGFR2',
#   'FGR',
#   'MAP4K2',
#   'MAPK3',
#   'MARK4',
#   'NEK6',
#   'PASK',
#   'PDGFRB',
#   'PIM3',
#   'PRKCA',
#   'PRKD2',
#   'PRKD3',
#   'ROCK2',
#   'TBK1'],
#  ['BMX',
#   'CHUK',
#   'CSNK1G3',
#   'EGFR',
#   'ERBB4',
#   'GSK3A',
#   'IRAK4',
#   'LTK',
#   'NEK9',
#   'NUAK1',
#   'PDGFRB',
#   'ROCK1',
#   'RPS6KA5',
#   'SIK2',
#   'TTK',
#   'TYK2'],
#  ['BRSK2', 'CHUK', 'EGFR', 'ROCK1', 'RPS6KA1', 'SIK2', 'TTK'],
#  ['AURKA',
#   'CDK2',
#   'CSNK1G3',
#   'DYRK2',
#   'EGFR',
#   'IKBKB',
#   'IKBKE',
#   'JAK2',
#   'LTK',
#   'MAPK3',
#   'MARK3',
#   'MUSK',
#   'PRKX',
#   'RPS6KA5',
#   'TYRO3'],
#  ['ABL1',
#   'CHUK',
#   'DYRK1B',
#   'EGFR',
#   'EPHB2',
#   'FLT3',
#   'LTK',
#   'MAP2K1',
#   'MAP4K2',
#   'MAPK11',
#   'MARK1',
#   'NUAK1',
#   'PRKD2',
#   'PRKX',
#   'ROCK2',
#   'SIK1',
#   'STK3',
#   'STK4',
#   'TYK2'],
#  ['ALK',
#   'AURKA',
#   'AURKC',
#   'AXL',
#   'CDK5',
#   'CSNK1G2',
#   'DDR2',
#   'EGFR',
#   'MAPK3',
#   'MAPK9',
#   'NEK9',
#   'ROCK2',
#   'TNK2',
#   'TSSK2'],
#  ['BRAF',
#   'CDC42BPB',
#   'CHUK',
#   'DYRK2',
#   'EGFR',
#   'EPHA2',
#   'FES',
#   'GSK3B',
#   'MAP2K1',
#   'MUSK',
#   'RAF1',
#   'ROCK1',
#   'SGK3',
#   'TTK'],
#  ['BMX',
#   'BRSK2',
#   'CDK2',
#   'CSNK1A1',
#   'GSK3A',
#   'INSRR',
#   'JAK3',
#   'KIT',
#   'LCK',
#   'LYN',
#   'MAP4K4',
#   'MAPK14',
#   'MST4',
#   'NEK1',
#   'PAK7',
#   'PIM3',
#   'PRKD3',
#   'RPS6KA2',
#   'RPS6KA3',
#   'SIK2',
#   'STK4',
#   'TTK'],
#  ['ABL2',
#   'AKT2',
#   'BTK',
#   'CAMK2D',
#   'CDK5',
#   'CSNK1G1',
#   'DDR2',
#   'EGFR',
#   'GSK3B',
#   'MAP4K4',
#   'MAPK11',
#   'MAPK14',
#   'MKNK2',
#   'MUSK',
#   'PAK3',
#   'PAK6',
#   'PASK',
#   'PDGFRB',
#   'PHKG2',
#   'PI4KB',
#   'PIM3',
#   'PRKD2',
#   'PRKX',
#   'RET',
#   'ROCK1',
#   'RPS6KA2',
#   'SGK3',
#   'SIK2',
#   'TNK2'],
#  ['AURKA',
#   'BRAF',
#   'BRSK2',
#   'CDC42BPB',
#   'CSF1R',
#   'CSNK1A1',
#   'EGFR',
#   'EPHA2',
#   'ERBB4',
#   'GSK3B',
#   'JAK2',
#   'LYN',
#   'MAP4K4',
#   'MAPK9',
#   'MKNK2',
#   'PRKCB',
#   'ROCK1',
#   'RPS6KA4',
#   'SIK2',
#   'TTK'],
#  ['ABL2',
#   'AXL',
#   'CDK1',
#   'CDK3',
#   'CHUK',
#   'CSNK1A1',
#   'DYRK1B',
#   'EGFR',
#   'EPHA3',
#   'FRK',
#   'GSK3A',
#   'JAK2',
#   'KIT',
#   'MAPK13',
#   'MARK4',
#   'MST1R',
#   'MUSK',
#   'PTK6',
#   'ROCK2',
#   'RPS6KA2',
#   'SRPK1'],
#  ['AXL',
#   'CHUK',
#   'EGFR',
#   'EPHA2',
#   'KIT',
#   'MKNK2',
#   'PAK6',
#   'PHKG2',
#   'PRKAA2',
#   'PTK6',
#   'ROCK1',
#   'STK3',
#   'STK4',
#   'SYK'],
#  ['BMX',
#   'CAMK2D',
#   'EGFR',
#   'ERBB4',
#   'FYN',
#   'GSK3A',
#   'JAK2',
#   'LRRK2',
#   'MAPK11',
#   'MUSK',
#   'NUAK1',
#   'PAK3',
#   'PDGFRB',
#   'ROCK1',
#   'RPS6KA2',
#   'RPS6KB1',
#   'SRMS',
#   'TTK'],
#  ['BRSK2',
#   'BTK',
#   'CSNK1G2',
#   'DYRK2',
#   'EGFR',
#   'FER',
#   'IKBKB',
#   'JAK2',
#   'MKNK2',
#   'PAK1',
#   'PDPK1',
#   'PIK3CD',
#   'PIM3',
#   'PRKACA',
#   'PRKX',
#   'PTK6',
#   'ROCK2',
#   'RPS6KA3',
#   'RPS6KA4',
#   'TTK',
#   'TYK2'],
#  ['BRSK1',
#   'CDK4',
#   'CHUK',
#   'EGFR',
#   'FER',
#   'JAK2',
#   'LTK',
#   'MARK2',
#   'MARK4',
#   'MET',
#   'MUSK',
#   'PAK2',
#   'PRKD1',
#   'PRKG1',
#   'ROCK1',
#   'RPS6KA3',
#   'SGK3',
#   'SRPK3'],
#  ['BMX',
#   'BRSK1',
#   'CDK2',
#   'CHUK',
#   'EGFR',
#   'ERBB4',
#   'HCK',
#   'IKBKB',
#   'NTRK2',
#   'PIK3CD',
#   'PRKD2',
#   'ROCK1',
#   'ROS1',
#   'RPS6KA3',
#   'RPS6KA5',
#   'RPS6KA6',
#   'RPS6KB1',
#   'SIK2',
#   'TSSK2',
#   'TTK',
#   'TXK'],
#  ['AKT2',
#   'ALK',
#   'ERBB4',
#   'FER',
#   'FLT1',
#   'GSK3A',
#   'JAK2',
#   'LCK',
#   'MAPK11',
#   'MERTK',
#   'MUSK',
#   'PAK6',
#   'PRKCB',
#   'PRKD2',
#   'ROCK2',
#   'RPS6KA4',
#   'RPS6KA6',
#   'SIK2'],
#  ['ABL1',
#   'AKT3',
#   'ALK',
#   'BLK',
#   'BMX',
#   'CDK3',
#   'CSK',
#   'DDR2',
#   'EGFR',
#   'ERBB2',
#   'FLT1',
#   'FLT3',
#   'HCK',
#   'IKBKE',
#   'ITK',
#   'LTK',
#   'MAPKAPK3',
#   'PAK6',
#   'PDGFRA',
#   'PHKG2',
#   'PIM2',
#   'PLK1',
#   'PRKACA',
#   'PRKCB',
#   'PRKD1',
#   'PRKG2',
#   'PTK6',
#   'RPS6KA5',
#   'SIK2',
#   'STK4',
#   'TXK'],
#  ['AURKC',
#   'CHUK',
#   'CSNK1A1',
#   'ERBB4',
#   'GSK3A',
#   'JAK3',
#   'LCK',
#   'MARK1',
#   'NEK6',
#   'NTRK1',
#   'PHKG2',
#   'PRKACA',
#   'ROCK2',
#   'SGK2',
#   'SIK2',
#   'TTK'],
#  ['BLK',
#   'BMX',
#   'CDK5',
#   'CHUK',
#   'CSK',
#   'DDR2',
#   'EGFR',
#   'EPHA4',
#   'ERBB4',
#   'FER',
#   'MAPK13',
#   'PASK',
#   'PI4KB',
#   'PRKACA',
#   'ROCK2',
#   'SIK2',
#   'TEK',
#   'TTK',
#   'YES1'],
#  ['AKT2',
#   'AURKC',
#   'CAMK4',
#   'CDC42BPA',
#   'CSNK1G2',
#   'EPHB3',
#   'FGFR4',
#   'GRK6',
#   'GSK3A',
#   'HCK',
#   'MST4',
#   'MUSK',
#   'PDGFRB',
#   'ROCK1',
#   'RPS6KA3',
#   'RPS6KA4',
#   'SGK2',
#   'TTK'],
#  ['ABL1',
#   'BMX',
#   'CSNK1G2',
#   'EGFR',
#   'GSK3A',
#   'IKBKB',
#   'IRAK4',
#   'JAK2',
#   'MKNK2',
#   'NEK2',
#   'PASK',
#   'PLK1',
#   'PTK6',
#   'RPS6KA1',
#   'TTK'],
#  ['AXL', 'EGFR', 'FER', 'IKBKE', 'ROCK1', 'SIK2', 'TTK'],
#  ['BLK',
#   'CAMK2D',
#   'CDC42BPB',
#   'CHEK1',
#   'CHEK2',
#   'CHUK',
#   'DCLK2',
#   'EGFR',
#   'EPHA4',
#   'EPHB2',
#   'ERBB4',
#   'FER',
#   'GSK3B',
#   'IRAK4',
#   'ITK',
#   'LCK',
#   'MAPKAPK3',
#   'MARK1',
#   'PIM2',
#   'PRKCA',
#   'PRKCG',
#   'PRKG2',
#   'PRKX',
#   'ROCK2',
#   'RPS6KA5',
#   'SRPK1',
#   'TEC',
#   'TNK2',
#   'TTK'],
#  ['BTK',
#   'CLK2',
#   'CSNK1G3',
#   'EGFR',
#   'ERBB4',
#   'FER',
#   'FLT1',
#   'FRK',
#   'GSK3A',
#   'MARK2',
#   'PAK3',
#   'PAK7',
#   'PRKAA2',
#   'PRKCB',
#   'ROCK1',
#   'SIK2',
#   'TBK1',
#   'TTK'],
#  ['AURKA',
#   'CDK2',
#   'CHEK2',
#   'CHUK',
#   'EGFR',
#   'MARK1',
#   'PRKX',
#   'ROS1',
#   'RPS6KA5',
#   'SIK2',
#   'TTK'],
#  ['BMX', 'CAMK4', 'CSNK1G2', 'EGFR', 'EPHA4', 'LTK', 'PAK2', 'ROCK2', 'STK4'],
#  ['AKT1',
#   'AURKB',
#   'AURKC',
#   'BRSK2',
#   'CDC42BPA',
#   'CHUK',
#   'CSK',
#   'EGFR',
#   'EPHB2',
#   'FGFR3',
#   'LTK',
#   'NUAK1',
#   'PRKCB',
#   'ROCK1',
#   'SGK3',
#   'STK3'],
#  ['AKT3',
#   'BMX',
#   'CSNK1G3',
#   'EGFR',
#   'EPHB3',
#   'ERBB4',
#   'MKNK2',
#   'NEK9',
#   'NUAK1',
#   'PRKACA',
#   'PRKX',
#   'ROS1',
#   'RPS6KA2',
#   'SGK3',
#   'SRPK1',
#   'TEC',
#   'TSSK2',
#   'TTK',
#   'ZAP70'],
#  ['AKT1',
#   'BMX',
#   'BTK',
#   'CSK',
#   'DYRK1B',
#   'EGFR',
#   'ERBB4',
#   'IRAK4',
#   'LYN',
#   'MAPKAPK2',
#   'MAPKAPK3',
#   'MAPKAPK5',
#   'MST1R',
#   'MUSK',
#   'NEK1',
#   'NUAK1',
#   'PIM2',
#   'PRKCG',
#   'PRKG1',
#   'ROCK2',
#   'RPS6KA2',
#   'SGK2',
#   'SIK1',
#   'SIK2',
#   'SRC',
#   'SRPK1',
#   'TSSK2',
#   'TTK'],
#  ['ABL1',
#   'AURKB',
#   'BTK',
#   'CDK2',
#   'CHEK1',
#   'CHEK2',
#   'DDR2',
#   'EGFR',
#   'KIT',
#   'MAPK3',
#   'MAPK9',
#   'MST4',
#   'PAK7',
#   'ROCK1',
#   'RPS6KA3',
#   'STK4'],
#  ['AKT1',
#   'BMX',
#   'BRSK2',
#   'CDK3',
#   'CSNK1A1',
#   'DYRK1B',
#   'EGFR',
#   'ERBB4',
#   'GSK3B',
#   'JAK2',
#   'JAK3',
#   'KIT',
#   'LRRK2',
#   'MAPKAPK3',
#   'MUSK',
#   'PASK',
#   'PIM2',
#   'ROCK2',
#   'RPS6KA6',
#   'STK3',
#   'TTK',
#   'TYRO3'],
#  ['BRSK1',
#   'BTK',
#   'CAMK4',
#   'CDK5',
#   'CLK3',
#   'CSK',
#   'CSNK1G2',
#   'DDR2',
#   'EGFR',
#   'FLT3',
#   'GSK3A',
#   'INSRR',
#   'JAK2',
#   'KDR',
#   'MAP2K1',
#   'MAP4K2',
#   'MAPKAPK3',
#   'MELK',
#   'MST1R',
#   'PAK6',
#   'PI4KB',
#   'PRKCB',
#   'PRKD2',
#   'PRKD3',
#   'ROCK2',
#   'RPS6KA4',
#   'RPS6KA5',
#   'SGK2',
#   'SIK2',
#   'STK4',
#   'TYK2'],
#  ['AXL',
#   'EGFR',
#   'FER',
#   'MAP2K1',
#   'MAPK13',
#   'MELK',
#   'PAK2',
#   'PAK3',
#   'PAK7',
#   'PIK3CD',
#   'ROCK2',
#   'STK3',
#   'TTK'],
#  ['BLK',
#   'GSK3B',
#   'KIT',
#   'MAPK11',
#   'MARK1',
#   'MKNK2',
#   'MUSK',
#   'NTRK1',
#   'PRKCB',
#   'TNK2'],
#  ['BMX',
#   'CAMK2D',
#   'CDC42BPB',
#   'CHEK1',
#   'CHUK',
#   'CSK',
#   'CSNK1G2',
#   'EGFR',
#   'GSK3B',
#   'HIPK1',
#   'MARK1',
#   'NUAK1',
#   'PDGFRB',
#   'PLK1',
#   'PRKCG',
#   'PRKG2',
#   'ROCK1',
#   'RPS6KA5',
#   'SGK3',
#   'SIK2',
#   'SRPK3',
#   'STK3'],
#  ['AKT3',
#   'BRSK2',
#   'CDK1',
#   'CHEK2',
#   'CSNK1G3',
#   'DYRK1A',
#   'EGFR',
#   'EPHB3',
#   'ERBB4',
#   'FLT4',
#   'IKBKB',
#   'IKBKE',
#   'INSRR',
#   'MAPKAPK3',
#   'MET',
#   'MST4',
#   'PASK',
#   'PDPK1',
#   'PIK3CD',
#   'PRKACA',
#   'PRKD1',
#   'PRKG2',
#   'ROCK2',
#   'ROS1',
#   'TSSK2',
#   'TTK'],
#  ['CHUK',
#   'EGFR',
#   'FLT1',
#   'FLT3',
#   'LTK',
#   'MAPK11',
#   'MAPK9',
#   'NEK6',
#   'PAK6',
#   'PRKCA',
#   'PTK6',
#   'ROCK1',
#   'SIK2',
#   'STK3'],
#  ['AURKB',
#   'AXL',
#   'BMX',
#   'CDK1',
#   'EGFR',
#   'FGR',
#   'KIT',
#   'MKNK2',
#   'ROCK1',
#   'SIK2',
#   'SRPK3',
#   'TTK'],
#  ['AURKC',
#   'CDK2',
#   'CDK5',
#   'CHEK2',
#   'CHUK',
#   'CSNK1A1',
#   'CSNK1G2',
#   'DAPK1',
#   'DCLK2',
#   'EGFR',
#   'EPHB4',
#   'ERBB4',
#   'GSK3A',
#   'HCK',
#   'JAK2',
#   'JAK3',
#   'LCK',
#   'MAP4K4',
#   'MAPKAPK2',
#   'MKNK2',
#   'NEK7',
#   'NTRK2',
#   'NTRK3',
#   'NUAK1',
#   'PAK7',
#   'PIK3CA',
#   'PRKD1',
#   'PRKG1',
#   'PTK6',
#   'ROCK2',
#   'SGK1',
#   'SGK3',
#   'SIK2',
#   'SRC',
#   'TBK1',
#   'TTK'],
#  ['CDC42BPB',
#   'CDK3',
#   'CHEK2',
#   'CLK3',
#   'CSNK1A1',
#   'DYRK1A',
#   'EGFR',
#   'ERBB4',
#   'ITK',
#   'LCK',
#   'MAPK11',
#   'MAPK12',
#   'MAPK3',
#   'PRKCG',
#   'PRKD3',
#   'RPS6KA3',
#   'SIK2',
#   'TEC',
#   'TTK',
#   'TXK'],
#  ['ALK',
#   'AURKA',
#   'AURKC',
#   'CAMK1D',
#   'CAMK4',
#   'CHUK',
#   'CSNK1A1',
#   'CSNK1G1',
#   'CSNK1G3',
#   'EPHB2',
#   'ERBB2',
#   'ERBB4',
#   'GSK3A',
#   'JAK1',
#   'LTK',
#   'LYN',
#   'MAPK12',
#   'MAPK14',
#   'PAK6',
#   'PDGFRB',
#   'PIM2',
#   'PLK1',
#   'PRKCB',
#   'PRKG1',
#   'PRKX',
#   'RPS6KA5',
#   'SGK2',
#   'SIK2',
#   'SRPK3',
#   'STK3',
#   'TSSK1B'],
#  ['CHEK2',
#   'CHUK',
#   'EGFR',
#   'FER',
#   'IKBKE',
#   'ITK',
#   'JAK1',
#   'NEK9',
#   'NTRK3',
#   'PIM2',
#   'ROCK1',
#   'RPS6KA3',
#   'SIK2',
#   'STK3',
#   'TTK'],
#  ['BMX',
#   'CAMK1D',
#   'CSF1R',
#   'EGFR',
#   'EPHA4',
#   'EPHB3',
#   'FGFR3',
#   'MAPK9',
#   'NEK6',
#   'NUAK1',
#   'PAK2',
#   'PIM1',
#   'PRKCB',
#   'ROCK1',
#   'RPS6KA6',
#   'SIK2',
#   'TTK',
#   'TYRO3'],
#  ['CDK3',
#   'CHEK2',
#   'CSF1R',
#   'CSK',
#   'DYRK1B',
#   'EGFR',
#   'ERBB4',
#   'KDR',
#   'MAP4K2',
#   'MAPK11',
#   'MARK1',
#   'NEK1',
#   'NEK9',
#   'PAK6',
#   'PAK7',
#   'PRKAA2',
#   'PRKG1',
#   'ROCK2',
#   'STK3',
#   'TTK'],
#  ['ALK',
#   'BRSK2',
#   'CAMK2A',
#   'CDK5',
#   'CHEK1',
#   'CLK3',
#   'CSNK1G2',
#   'DYRK1B',
#   'EGFR',
#   'ERBB4',
#   'IKBKE',
#   'INSRR',
#   'LYN',
#   'MAP2K1',
#   'MAP4K2',
#   'MARK2',
#   'MKNK2',
#   'NEK1',
#   'NTRK2',
#   'PIK3CD',
#   'PRKCA',
#   'PRKG1',
#   'ROCK1',
#   'RPS6KB1',
#   'SGK1',
#   'STK4',
#   'SYK',
#   'TTK'],
#  ['AURKC',
#   'CDK3',
#   'CHEK1',
#   'CSF1R',
#   'CSK',
#   'DDR2',
#   'EGFR',
#   'EPHB2',
#   'ERBB4',
#   'FER',
#   'HIPK1',
#   'KDR',
#   'MARK2',
#   'MERTK',
#   'MST1R',
#   'NEK7',
#   'NUAK1',
#   'PRKCB',
#   'PRKD3',
#   'ROCK1',
#   'SIK2',
#   'TEC',
#   'TTK'],
#  ['ABL1',
#   'CAMK4',
#   'CDK5',
#   'CHEK2',
#   'CSK',
#   'CSNK1A1',
#   'EGFR',
#   'ERBB4',
#   'GSK3B',
#   'IKBKE',
#   'MAPK11',
#   'MKNK2',
#   'NEK9',
#   'PAK1',
#   'PIM2',
#   'ROCK1',
#   'RPS6KA3',
#   'SGK2',
#   'SIK2',
#   'TTK',
#   'ZAP70'],
#  ['AKT2',
#   'BLK',
#   'CDK3',
#   'CHUK',
#   'DYRK1A',
#   'EGFR',
#   'EPHB2',
#   'FGFR4',
#   'FGR',
#   'FLT3',
#   'IKBKB',
#   'MAP4K4',
#   'MAPKAPK5',
#   'NEK6',
#   'NEK9',
#   'PAK3',
#   'PDPK1',
#   'PRKCB',
#   'ROCK2',
#   'ROS1',
#   'RPS6KA6',
#   'RPS6KB1',
#   'SGK3',
#   'SIK2',
#   'STK3',
#   'TBK1',
#   'TTK'],
#  ['ABL2',
#   'AKT3',
#   'CHUK',
#   'CSF1R',
#   'DCLK2',
#   'DYRK1A',
#   'EGFR',
#   'FGR',
#   'MAPK9',
#   'MAPKAPK3',
#   'MARK3',
#   'MERTK',
#   'MKNK2',
#   'NUAK1',
#   'PASK',
#   'PRKD2',
#   'RET',
#   'ROCK1',
#   'RPS6KA1',
#   'TTK'],
#  ['AKT2',
#   'AURKC',
#   'CAMK2A',
#   'CDK2',
#   'CSK',
#   'CSNK1G1',
#   'EGFR',
#   'EPHB3',
#   'ERBB4',
#   'FLT3',
#   'GSK3A',
#   'KIT',
#   'LCK',
#   'LYN',
#   'MAPKAPK3',
#   'MINK1',
#   'PAK2',
#   'PIM2',
#   'ROCK2',
#   'RPS6KA2',
#   'SGK2',
#   'TTK'],
#  ['CDC42BPA',
#   'CDC42BPB',
#   'CSK',
#   'EGFR',
#   'EPHB3',
#   'GSK3B',
#   'IKBKE',
#   'KIT',
#   'LCK',
#   'LTK',
#   'MAPK13',
#   'MAPK3',
#   'MARK2',
#   'PASK',
#   'PRKAA2',
#   'PRKD2',
#   'PRKX',
#   'PTK6',
#   'RPS6KA1',
#   'RPS6KA3',
#   'SIK1',
#   'SIK2',
#   'SRMS',
#   'SRPK3'],
#  ['AKT1',
#   'AKT3',
#   'CDK2',
#   'CDK3',
#   'CHUK',
#   'DCLK2',
#   'EGFR',
#   'FRK',
#   'FYN',
#   'GSK3A',
#   'MAPK12',
#   'MAPKAPK3',
#   'MST1R',
#   'MUSK',
#   'PRKCB',
#   'ROCK2',
#   'RPS6KA4',
#   'RPS6KA6',
#   'SIK1',
#   'TEC'],
#  ['CHEK2',
#   'CHUK',
#   'DCLK2',
#   'EGFR',
#   'LTK',
#   'NEK1',
#   'NEK9',
#   'PDPK1',
#   'RPS6KA1',
#   'RPS6KA5',
#   'STK4',
#   'ZAP70'],
#  ['BRAF',
#   'CDK2',
#   'CDK3',
#   'CHEK1',
#   'CHEK2',
#   'CHUK',
#   'EGFR',
#   'IKBKE',
#   'JAK2',
#   'PASK',
#   'PDPK1',
#   'PIM2',
#   'ROCK2',
#   'SIK2',
#   'TTK'],
#  ['DYRK1A',
#   'EGFR',
#   'IKBKB',
#   'LTK',
#   'MAPK13',
#   'MAPK9',
#   'MARK2',
#   'MUSK',
#   'PRKAA2',
#   'PRKG2',
#   'ROCK1',
#   'RPS6KA2',
#   'RPS6KA3',
#   'SGK3',
#   'SIK2'],
#  ['ALK',
#   'BMX',
#   'CAMK1D',
#   'CHEK2',
#   'CLK2',
#   'EGFR',
#   'EPHB4',
#   'FLT3',
#   'IKBKE',
#   'MAPK11',
#   'MAPK13',
#   'MST4',
#   'PHKG1',
#   'PRKCA',
#   'PRKCB',
#   'PRKD3',
#   'RAF1',
#   'SIK2',
#   'STK4',
#   'TEC',
#   'TNK2',
#   'TTK'],
#  ['CAMK2D', 'CHUK', 'EGFR', 'MELK', 'ROCK2', 'ROS1', 'SIK2', 'TTK'],
#  ['BMX',
#   'BRSK2',
#   'CHUK',
#   'EGFR',
#   'MELK',
#   'PHKG1',
#   'PRKAA2',
#   'PRKACA',
#   'PRKD1',
#   'ROCK1',
#   'TTK'],
#  ['AXL',
#   'CHUK',
#   'EGFR',
#   'IKBKE',
#   'JAK2',
#   'LTK',
#   'PASK',
#   'PDPK1',
#   'ROCK1',
#   'TBK1'],
#  ['ALK',
#   'BMX',
#   'CDK4',
#   'CHUK',
#   'EGFR',
#   'FER',
#   'FYN',
#   'GSK3A',
#   'GSK3B',
#   'IKBKB',
#   'KIT',
#   'LCK',
#   'LTK',
#   'MAPKAPK5',
#   'MINK1',
#   'MST1R',
#   'PAK2',
#   'PAK6',
#   'PDGFRA',
#   'RET',
#   'ROCK1',
#   'SRC',
#   'TXK',
#   'TYRO3',
#   'YES1'],
#  ['CDK2',
#   'CDK6',
#   'CLK3',
#   'DYRK1B',
#   'EGFR',
#   'EPHB2',
#   'FES',
#   'FGR',
#   'GSK3B',
#   'INSRR',
#   'KIT',
#   'LCK',
#   'LRRK2',
#   'MAPKAPK2',
#   'MET',
#   'MST1R',
#   'PDGFRB',
#   'PHKG1',
#   'PI4KB',
#   'PRKACA',
#   'PRKCB',
#   'PRKG2',
#   'ROCK2',
#   'RPS6KA2',
#   'SGK1',
#   'SIK2',
#   'STK10',
#   'TNK2',
#   'TSSK2'],
#  ['ABL2',
#   'ALK',
#   'CDK1',
#   'CHUK',
#   'CSNK1G1',
#   'EGFR',
#   'EPHA3',
#   'IKBKE',
#   'JAK2',
#   'LRRK2',
#   'MAPKAPK5',
#   'MUSK',
#   'NTRK2',
#   'PDPK1',
#   'RPS6KA2',
#   'SIK1',
#   'SIK2',
#   'SRPK1',
#   'TEC'],
#  ['AXL',
#   'BRSK1',
#   'CSNK1A1',
#   'EGFR',
#   'ERBB4',
#   'JAK2',
#   'KIT',
#   'MAP4K4',
#   'MAPK11',
#   'PRKCB',
#   'PRKG2',
#   'RAF1',
#   'ROCK1',
#   'RPS6KA1',
#   'SRPK3',
#   'TTK',
#   'ZAP70'],
#  ['AKT3',
#   'AURKB',
#   'CDK1',
#   'EGFR',
#   'KIT',
#   'LCK',
#   'LRRK2',
#   'MAPK1',
#   'MAPK14',
#   'MARK2',
#   'PRKD1',
#   'RET',
#   'ROCK1',
#   'SIK2',
#   'SRC',
#   'TEC',
#   'TNK2',
#   'TXK'],
#  ['AXL',
#   'CAMK2D',
#   'CAMK4',
#   'CDK6',
#   'CHEK1',
#   'CSNK1A1',
#   'EGFR',
#   'ERBB4',
#   'GSK3B',
#   'LCK',
#   'LYN',
#   'MARK2',
#   'MUSK',
#   'NEK7',
#   'NTRK2',
#   'PRKD1',
#   'ROCK1',
#   'RPS6KA1',
#   'SIK2',
#   'TBK1'],
#  ['AURKC',
#   'CDK2',
#   'CDK5',
#   'DAPK1',
#   'DDR2',
#   'EGFR',
#   'FER',
#   'FRK',
#   'LTK',
#   'MAPK3',
#   'PAK6',
#   'PIK3CD',
#   'RAF1',
#   'ROCK2'],
#  ['CAMK2D',
#   'CDK1',
#   'CDK2',
#   'DAPK1',
#   'DYRK1B',
#   'EGFR',
#   'ERBB4',
#   'GSK3B',
#   'IRAK4',
#   'ITK',
#   'JAK2',
#   'LRRK2',
#   'MAPK1',
#   'MUSK',
#   'NTRK1',
#   'NUAK1',
#   'PAK6',
#   'PI4KB',
#   'PRKG2',
#   'ROCK2',
#   'RPS6KA1',
#   'RPS6KA3',
#   'RPS6KA5',
#   'SIK1'],
#  ['AXL',
#   'BMX',
#   'CHUK',
#   'CSNK1G3',
#   'DYRK1A',
#   'EGFR',
#   'HCK',
#   'IKBKE',
#   'ROCK1',
#   'RPS6KA3',
#   'SIK2',
#   'TTK'],
#  ['ABL1',
#   'AKT3',
#   'BMX',
#   'CSK',
#   'CSNK1G2',
#   'EGFR',
#   'FGR',
#   'GSK3B',
#   'INSRR',
#   'LTK',
#   'MAPKAPK3',
#   'MKNK2',
#   'MUSK',
#   'NEK6',
#   'PAK7',
#   'ROCK1',
#   'RPS6KA3'],
#  ['BRAF',
#   'CSK',
#   'CSNK1G2',
#   'DCLK2',
#   'EGFR',
#   'LTK',
#   'MARK3',
#   'MUSK',
#   'NTRK2',
#   'PAK6',
#   'PHKG2',
#   'PRKD2',
#   'PRKD3',
#   'PTK6',
#   'RPS6KA5',
#   'TYRO3'],
#  ['AURKA',
#   'BRSK1',
#   'CDK1',
#   'CDK4',
#   'CSF1R',
#   'CSK',
#   'DYRK1A',
#   'EGFR',
#   'EPHA4',
#   'ERBB4',
#   'FLT4',
#   'LRRK2',
#   'NTRK1',
#   'PIM2',
#   'ROCK2',
#   'ROS1',
#   'RPS6KA2',
#   'RPS6KB1',
#   'SIK2',
#   'TTK',
#   'ZAP70'],
#  ['AKT3',
#   'BRSK1',
#   'CHUK',
#   'DYRK1B',
#   'EGFR',
#   'ITK',
#   'MARK2',
#   'NTRK2',
#   'ROCK1',
#   'ROS1',
#   'RPS6KA2',
#   'RPS6KA5',
#   'TNK2',
#   'TTK'],
#  ['AXL',
#   'CAMK1D',
#   'CHUK',
#   'CSK',
#   'CSNK1A1',
#   'DDR2',
#   'EGFR',
#   'GSK3A',
#   'HCK',
#   'IKBKB',
#   'KIT',
#   'LTK',
#   'MKNK1',
#   'NTRK3',
#   'NUAK1',
#   'PAK3',
#   'PRKCG',
#   'ROCK1',
#   'RPS6KA2',
#   'SIK2',
#   'SRMS'],
#  ['AURKA',
#   'BLK',
#   'CHUK',
#   'CSNK1A1',
#   'CSNK1G3',
#   'ERBB4',
#   'FER',
#   'GSK3B',
#   'ITK',
#   'LTK',
#   'MAP4K2',
#   'MAPK9',
#   'MARK4',
#   'NEK1',
#   'PIM2',
#   'ROCK1',
#   'RPS6KA2',
#   'RPS6KB1',
#   'SGK1',
#   'TSSK2'],
#  ['BMX',
#   'CHUK',
#   'EGFR',
#   'FER',
#   'FGFR3',
#   'FGFR4',
#   'GSK3A',
#   'LTK',
#   'MAPK13',
#   'MERTK',
#   'PDGFRB',
#   'PRKG1',
#   'ROCK1',
#   'RPS6KA1',
#   'RPS6KA5',
#   'SGK3',
#   'TEC'],
#  ['CDC42BPA',
#   'CDC42BPB',
#   'CDK3',
#   'CHUK',
#   'EGFR',
#   'ERBB2',
#   'IKBKE',
#   'JAK2',
#   'LTK',
#   'MAP2K1',
#   'MAPKAPK3',
#   'MARK2',
#   'PI4KB',
#   'PIM2',
#   'ROCK1',
#   'RPS6KA1',
#   'RPS6KA2',
#   'SGK2'],
#  ['ALK',
#   'BRAF',
#   'CAMK1D',
#   'CHUK',
#   'CSF1R',
#   'EGFR',
#   'EPHA2',
#   'ERBB2',
#   'FER',
#   'FES',
#   'IKBKB',
#   'IRAK4',
#   'JAK2',
#   'MERTK',
#   'PDGFRA',
#   'PIM1',
#   'ROCK2',
#   'RPS6KA3',
#   'RPS6KA4',
#   'SIK2',
#   'SRC',
#   'ZAP70'],
#  ['ABL1',
#   'BRSK1',
#   'CSF1R',
#   'CSK',
#   'EGFR',
#   'IKBKE',
#   'JAK2',
#   'LYN',
#   'MAPK13',
#   'MKNK2',
#   'ROCK2',
#   'TTK',
#   'TXK',
#   'TYRO3',
#   'YES1'],
#  ['ABL2',
#   'AKT2',
#   'BRAF',
#   'CAMK4',
#   'CDK1',
#   'CSF1R',
#   'CSNK1G1',
#   'DDR2',
#   'EGFR',
#   'EPHB4',
#   'FER',
#   'HCK',
#   'MAPK12',
#   'MAPKAPK3',
#   'MUSK',
#   'PAK6',
#   'PIK3CD',
#   'PRKD3',
#   'ROCK2',
#   'SGK1',
#   'SIK2',
#   'TNK2',
#   'TSSK1B',
#   'TTK'],
#  ['AKT2',
#   'AXL',
#   'CDC42BPB',
#   'CHUK',
#   'ERBB4',
#   'GSK3A',
#   'HIPK1',
#   'JAK2',
#   'KIT',
#   'MAPK14',
#   'ROCK2',
#   'RPS6KA2',
#   'RPS6KA3',
#   'SGK1',
#   'SRPK3'],
#  ['CDK1',
#   'CHUK',
#   'EGFR',
#   'FGFR4',
#   'GRK6',
#   'PLK1',
#   'ROCK2',
#   'SIK2',
#   'STK4',
#   'TTK'],
#  ['AKT1',
#   'AXL',
#   'BRSK2',
#   'BTK',
#   'CDC42BPB',
#   'CLK3',
#   'EGFR',
#   'EPHA2',
#   'EPHB2',
#   'EPHB4',
#   'ERBB4',
#   'LYN',
#   'MAPKAPK3',
#   'MST4',
#   'NTRK2',
#   'PASK',
#   'PHKG2',
#   'PIK3CD',
#   'RAF1',
#   'ROCK1',
#   'STK3',
#   'TTK']]

# %%
k_cnts = {}
for l in kin:
    for k in l:
        if k in k_cnts:
            k_cnts[k] += 1
        else:
            k_cnts[k] = 1

# %%
k_cnts
# Out:
# {'ABL1': 10,
#  'ABL2': 7,
#  'AKT1': 6,
#  'AKT2': 8,
#  'AKT3': 9,
#  'ALK': 13,
#  'AURKA': 11,
#  'AURKB': 5,
#  'AURKC': 10,
#  'AXL': 14,
#  'BLK': 8,
#  'BMX': 21,
#  'BRAF': 6,
#  'BRSK1': 8,
#  'BRSK2': 14,
#  'BTK': 10,
#  'CAMK1D': 7,
#  'CAMK2A': 3,
#  'CAMK2D': 9,
#  'CAMK4': 9,
#  'CDC42BPA': 6,
#  'CDC42BPB': 9,
#  'CDK1': 13,
#  'CDK2': 16,
#  'CDK3': 11,
#  'CDK4': 4,
#  'CDK5': 10,
#  'CDK6': 3,
#  'CHEK1': 8,
#  'CHEK2': 14,
#  'CHUK': 43,
#  'CLK2': 2,
#  'CLK3': 6,
#  'CSF1R': 11,
#  'CSK': 17,
#  'CSNK1A1': 20,
#  'CSNK1G1': 6,
#  'CSNK1G2': 12,
#  'CSNK1G3': 11,
#  'DAPK1': 5,
#  'DCLK2': 8,
#  'DDR2': 13,
#  'DYRK1A': 8,
#  'DYRK1B': 11,
#  'DYRK2': 4,
#  'EGFR': 90,
#  'EPHA2': 5,
#  'EPHA3': 4,
#  'EPHA4': 6,
#  'EPHB2': 8,
#  'EPHB3': 7,
#  'EPHB4': 5,
#  'ERBB2': 7,
#  'ERBB4': 39,
#  'FER': 18,
#  'FES': 5,
#  'FGFR2': 1,
#  'FGFR3': 4,
#  'FGFR4': 6,
#  'FGR': 10,
#  'FLT1': 6,
#  'FLT3': 8,
#  'FLT4': 3,
#  'FRK': 6,
#  'FYN': 5,
#  'GRK6': 4,
#  'GSK3A': 25,
#  'GSK3B': 16,
#  'HCK': 8,
#  'HIPK1': 3,
#  'IKBKB': 11,
#  'IKBKE': 18,
#  'INSRR': 6,
#  'IRAK4': 9,
#  'ITK': 8,
#  'JAK1': 5,
#  'JAK2': 24,
#  'JAK3': 4,
#  'KDR': 3,
#  'KIT': 20,
#  'LCK': 12,
#  'LRRK2': 11,
#  'LTK': 25,
#  'LYN': 10,
#  'MAP2K1': 7,
#  'MAP4K2': 6,
#  'MAP4K4': 8,
#  'MAPK1': 3,
#  'MAPK11': 13,
#  'MAPK12': 5,
#  'MAPK13': 9,
#  'MAPK14': 8,
#  'MAPK3': 8,
#  'MAPK9': 9,
#  'MAPKAPK2': 5,
#  'MAPKAPK3': 13,
#  'MAPKAPK5': 6,
#  'MARK1': 7,
#  'MARK2': 11,
#  'MARK3': 4,
#  'MARK4': 8,
#  'MELK': 6,
#  'MERTK': 7,
#  'MET': 4,
#  'MINK1': 3,
#  'MKNK1': 2,
#  'MKNK2': 17,
#  'MST1R': 8,
#  'MST4': 7,
#  'MUSK': 26,
#  'NEK1': 7,
#  'NEK2': 2,
#  'NEK6': 6,
#  'NEK7': 3,
#  'NEK9': 8,
#  'NTRK1': 6,
#  'NTRK2': 9,
#  'NTRK3': 5,
#  'NUAK1': 16,
#  'PAK1': 4,
#  'PAK2': 8,
#  'PAK3': 6,
#  'PAK6': 16,
#  'PAK7': 7,
#  'PASK': 12,
#  'PDGFRA': 3,
#  'PDGFRB': 9,
#  'PDPK1': 9,
#  'PHKG1': 3,
#  'PHKG2': 8,
#  'PI4KB': 6,
#  'PIK3CA': 4,
#  'PIK3CD': 8,
#  'PIM1': 2,
#  'PIM2': 12,
#  'PIM3': 4,
#  'PLK1': 7,
#  'PRKAA2': 6,
#  'PRKACA': 8,
#  'PRKCA': 5,
#  'PRKCB': 16,
#  'PRKCG': 6,
#  'PRKD1': 8,
#  'PRKD2': 11,
#  'PRKD3': 9,
#  'PRKG1': 11,
#  'PRKG2': 10,
#  'PRKX': 15,
#  'PTK6': 10,
#  'RAF1': 5,
#  'RET': 4,
#  'ROCK1': 46,
#  'ROCK2': 37,
#  'ROS1': 9,
#  'RPS6KA1': 13,
#  'RPS6KA2': 20,
#  'RPS6KA3': 21,
#  'RPS6KA4': 8,
#  'RPS6KA5': 16,
#  'RPS6KA6': 7,
#  'RPS6KB1': 6,
#  'SGK1': 7,
#  'SGK2': 10,
#  'SGK3': 13,
#  'SIK1': 7,
#  'SIK2': 49,
#  'SRC': 7,
#  'SRMS': 8,
#  'SRPK1': 6,
#  'SRPK3': 9,
#  'STK10': 1,
#  'STK3': 16,
#  'STK4': 14,
#  'SYK': 3,
#  'TBK1': 7,
#  'TEC': 9,
#  'TEK': 2,
#  'TNK2': 9,
#  'TSSK1B': 2,
#  'TSSK2': 7,
#  'TTK': 52,
#  'TXK': 7,
#  'TYK2': 4,
#  'TYRO3': 6,
#  'YES1': 4,
#  'ZAP70': 7}

# %%
kin_cnt_ser = pd.Series(list(k_cnts.values()), index=k_cnts.keys())

# %%
kin_cnt_ser.sort_values(ascending=False, inplace=True)

# %%
kin_cnt_ser
# Out:
# EGFR       90
# TTK        52
# SIK2       49
# ROCK1      46
# CHUK       43
# ERBB4      39
# ROCK2      37
# MUSK       26
# GSK3A      25
# LTK        25
# JAK2       24
# RPS6KA3    21
# BMX        21
# RPS6KA2    20
# CSNK1A1    20
# KIT        20
# FER        18
# IKBKE      18
# MKNK2      17
# CSK        17
# STK3       16
# PAK6       16
# NUAK1      16
# RPS6KA5    16
# CDK2       16
# PRKCB      16
# GSK3B      16
# PRKX       15
# AXL        14
# CHEK2      14
#            ..
# YES1        4
# FGFR3       4
# MARK3       4
# RET         4
# PIK3CA      4
# EPHA3       4
# JAK3        4
# TYK2        4
# PIM3        4
# DYRK2       4
# MET         4
# PDGFRA      3
# NEK7        3
# CAMK2A      3
# PHKG1       3
# KDR         3
# SYK         3
# MAPK1       3
# CDK6        3
# FLT4        3
# MINK1       3
# HIPK1       3
# TSSK1B      2
# PIM1        2
# NEK2        2
# CLK2        2
# TEK         2
# MKNK1       2
# FGFR2       1
# STK10       1
# Length: 186, dtype: int64

# %%
groups = []
with open('linked_groups.csv', 'r') as f:
    for line in f:
        groups.append(line.strip().split(','))
for i in range(len(groups)):
    groups[i] = set(groups[i])

# %%
groups
# Out:
# [{'TNK2'},
#  {'ROCK1', 'ROCK2'},
#  {'PIK3CB', 'PIK3CD'},
#  {'PRKCA', 'PRKCB', 'PRKCG'},
#  {'CDK1', 'CDK2', 'CDK3', 'CDK4', 'CDK5', 'CDK6'},
#  {'RPS6KA1', 'RPS6KA2', 'RPS6KA3', 'RPS6KA4', 'RPS6KA5', 'RPS6KA6'},
#  {'PRKG1', 'PRKG2'},
#  {'MAPKAPK2', 'MAPKAPK3'},
#  {'PRKX', 'PRKY'},
#  {'MAPK11', 'MAPK12', 'MAPK13', 'MAPK14'},
#  {'MAP4K4', 'MINK1', 'TNIK'},
#  {'MUSK'},
#  {'BLK', 'FGR', 'FYN', 'HCK', 'LCK', 'LYN', 'SRC', 'YES1'},
#  {'EGFR', 'ERBB2', 'ERBB4'},
#  {'FLT4'}]

# %%
sum = 0
for g in groups:
    sum += len(g)
print(sum)
print(190-sum)
# Out:
# 46
# 144

# %%
new_col = [-2 for i in range(len(kin_cnt_ser.index))]
for i in range(len(kin_cnt_ser.index)):
    for j in range(len(groups)):
        if kin_cnt_ser.index[i] in groups[j]:
            new_col[i] = j
            continue
    if new_col[i] == -2:
        new_col[i] = -1

# %%
-2 in new_col
# Out:
# False

# %%
kin_cnt_df = pd.DataFrame({'Count': kin_cnt_ser, 'Group': new_col})

# %%
kin_cnt_df
# Out:
#          Count  Group
# EGFR        90     13
# TTK         52     -1
# SIK2        49     -1
# ROCK1       46      1
# CHUK        43     -1
# ERBB4       39     13
# ROCK2       37      1
# MUSK        26     11
# GSK3A       25     -1
# LTK         25     -1
# JAK2        24     -1
# RPS6KA3     21      5
# BMX         21     -1
# RPS6KA2     20      5
# CSNK1A1     20     -1
# KIT         20     -1
# FER         18     -1
# IKBKE       18     -1
# MKNK2       17     -1
# CSK         17     -1
# STK3        16     -1
# PAK6        16     -1
# NUAK1       16     -1
# RPS6KA5     16      5
# CDK2        16      4
# PRKCB       16      3
# GSK3B       16     -1
# PRKX        15      8
# AXL         14     -1
# CHEK2       14     -1
# ...        ...    ...
# YES1         4     12
# FGFR3        4     -1
# MARK3        4     -1
# RET          4     -1
# PIK3CA       4     -1
# EPHA3        4     -1
# JAK3         4     -1
# TYK2         4     -1
# PIM3         4     -1
# DYRK2        4     -1
# MET          4     -1
# PDGFRA       3     -1
# NEK7         3     -1
# CAMK2A       3     -1
# PHKG1        3     -1
# KDR          3     -1
# SYK          3     -1
# MAPK1        3     -1
# CDK6         3      4
# FLT4         3     14
# MINK1        3     10
# HIPK1        3     -1
# TSSK1B       2     -1
# PIM1         2     -1
# NEK2         2     -1
# CLK2         2     -1
# TEK          2     -1
# MKNK1        2     -1
# FGFR2        1     -1
# STK10        1     -1
#
# [186 rows x 2 columns]

# %%
# Testing my code to make sure it does what I want on toy data
results = np.zeros(24).reshape((6, 4)).astype(bool)
a = [{1, 2, 3}, {4, 5}, {6, 7}]
b = [[1, 2], [1, 4], [3, 4, 5, 6], [4, 6], [4, 23], [23, 56, 48]]
for i in range(len(b)):
    for j in range(len(b[i])):
        for k in range(len(a)):
            if b[i][j] in a[k]:
                results[i, k] = True
                break
        else:
            results[i, -1] = True
results
# Out:
# array([[ True, False, False, False],
#        [ True,  True, False, False],
#        [ True,  True,  True, False],
#        [False,  True,  True, False],
#        [False,  True, False,  True],
#        [False, False, False,  True]])

# %%
in_groups = np.zeros(1600).reshape((100, 16)).astype(bool)

# %%
for i in range(len(kin)):
    for j in range(len(kin[i])):
        for k in range(len(groups)):
            if kin[i][j] in groups[k]:
                in_groups[i, k] = True
                break
        else:
            in_groups[i, -1] = True

# %%
group_representation = np.zeros(16)
for i in range(in_groups.shape[0]):
    for j in range(in_groups.shape[1]):
        if in_groups[i, j]:
            group_representation[j] += 1

# %%
group_representation
# Out:
# array([  9.,  83.,   8.,  25.,  48.,  62.,  21.,  17.,  15.,  31.,  11.,
#         26.,  46.,  96.,   3., 100.])

# %%
group_frequencies = group_representation / np.array([len(g) for g in groups] + [144])

# %%
group_frequencies
# Out:
# array([ 9.        , 41.5       ,  4.        ,  8.33333333,  8.        ,
#        10.33333333, 10.5       ,  8.5       ,  7.5       ,  7.75      ,
#         3.66666667, 26.        ,  5.75      , 32.        ,  3.        ,
#         0.69444444])

# %%
plt.style.use('ggplot')
labels = [str(i+1) for i in range(15)] + ['N/A']
fig, ax = plt.subplots()
fig.set_size_inches((12, 8.25))
ax.bar([i+1 for i in range(16)], group_frequencies, tick_label=labels, align='center', color='#2f8cb5')
ax.set_xlabel('Group Number', size=14)
ax.set_xlim((0, 17))
ax.set_ylabel('Frequency of Inclusion (Normalized to Group Size)', size=14)
ax.set_title('Frequency of Inclusion of At Least 1 Member of Each Group',
             size='20')
ax.tick_params(axis='both', pad=8, labelsize=12)
fig.set_facecolor('#ffffff')
plt.savefig('figures/Frequency_of_Inclusion_Normalized.png', dpi=300, format='png',
            bbox_inches='tight')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['classic', 'Solarize_Light2', 'grayscale', 'fast', 'fivethirtyeight', 'seaborn-dark-palette', 'seaborn-whitegrid', 'seaborn-dark', 'seaborn-colorblind', '_classic_test', 'ggplot', 'seaborn-talk', 'bmh', 'seaborn-darkgrid', 'seaborn-notebook', 'dark_background', 'seaborn-muted', 'seaborn', 'seaborn-pastel', 'seaborn-poster', 'seaborn-paper', 'seaborn-ticks', 'seaborn-bright', 'seaborn-deep', 'seaborn-white']

# %%
for s in plt.style.available:
    plt.style.use(s)
    labels = [str(i+1) for i in range(15)] + ['N/A']
    fig, ax = plt.subplots()
    fig.set_size_inches((12, 8.25))
    ax.bar([i for i in range(16)], group_frequencies, tick_label=labels)
    ax.set_xlabel('Group Number')
    ax.set_ylabel('Frequency of Inclusion (Normalized to Group Size)')
    ax.set_title(s)
    plt.savefig('test_styles/{}.png'.format(s))
    plt.close()

# %%
print(groups[1])
print(groups[11])
print(groups[13])
# Out:
# {'ROCK1', 'ROCK2'}
# {'MUSK'}
# {'ERBB2', 'ERBB4', 'EGFR'}

# %%
rock = 0
double_rock = 0
for g in kin:
    if 'ROCK1' in g:
        rock += 1
        if 'ROCK2' in g:
            double_rock += 1
            continue
    elif 'ROCK2' in g:
        rock += 1
print(rock)
print(double_rock)
# Out:
# 83
# 0

# %%
{'ERBB2', 'ERBB4', 'EGFR'}
e_count = [0, 0, 0]
for g in kin:
    flag = 0
    if 'ERBB2' in g:
        flag += 1
    if 'ERBB4' in g:
        flag += 1
    if 'EGFR' in g:
        flag += 1
    if flag > 0:
        e_count[flag - 1] += 1
e_count
# Out:
# [57, 38, 1]

# %%
high_kin_cnt_df = kin_cnt_df[kin_cnt_df['Count'] >= 33]
high_kin_cnt_df
# Out:
#        Count  Group
# EGFR      90     13
# TTK       52     -1
# SIK2      49     -1
# ROCK1     46      1
# CHUK      43     -1
# ERBB4     39     13
# ROCK2     37      1

# %%
scores = pd.read_csv('numerical_data.csv')

# %%
scores.head()
# Out:
#    Unnamed: 0  num_features  g_fitness  g_accuracy  g_sensitivity  \
# 0         199          15.0   0.716831    0.765094       0.612500
# 1         199          10.0   0.730147    0.813083       0.589286
# 2         199          14.0   0.557276    0.772655       0.444643
# 3         199          21.0   0.702287    0.812917       0.558929
# 4         199          33.0   0.703672    0.796074       0.592857
#
#    g_specificity  a_fitness  a_accuracy  a_sensitivity  a_specificity
# 0       0.825146   0.747828    0.813248       0.639286       0.880994
# 1       0.901462   0.754557    0.847897       0.621429       0.935088
# 2       0.901170   0.755986    0.839909       0.637500       0.919298
# 3       0.912865   0.750572    0.843447       0.639286       0.923392
# 4       0.874854   0.727014    0.804051       0.641071       0.868713

# %%
scores.drop(['Unnamed: 0', 'g_fitness', 'g_accuracy', 'g_sensitivity', 'g_specificity'], axis=1, inplace=True)

# %%
scores.head()
# Out:
#    num_features  a_fitness  a_accuracy  a_sensitivity  a_specificity
# 0          15.0   0.747828    0.813248       0.639286       0.880994
# 1          10.0   0.754557    0.847897       0.621429       0.935088
# 2          14.0   0.755986    0.839909       0.637500       0.919298
# 3          21.0   0.750572    0.843447       0.639286       0.923392
# 4          33.0   0.727014    0.804051       0.641071       0.868713

# %%
scores.describe()
# Out:
#        num_features   a_fitness  a_accuracy  a_sensitivity  a_specificity
# count    100.000000  100.000000  100.000000     100.000000     100.000000
# mean      18.970000    0.745256    0.822147       0.637161       0.894547
# std        5.944958    0.018232    0.019982       0.029335       0.029140
# min        7.000000    0.699275    0.754883       0.569643       0.816374
# 25%       15.000000    0.732828    0.808795       0.615625       0.874927
# 50%       18.500000    0.747001    0.821897       0.639286       0.892105
# 75%       22.000000    0.755456    0.836964       0.654018       0.919079
# max       36.000000    0.804948    0.863305       0.735714       0.956140

# %%
control_scores = pd.read_csv('control_scores.csv')
control_scores.head()
# Out:
#    num_of_features  accuracy  sensitivity  specificity
# 0              190  0.773259     0.373214     0.930117
# 1              190  0.779909     0.383929     0.933918
# 2              190  0.772832     0.369643     0.929532
# 3              190  0.777390     0.389286     0.929532
# 4              190  0.773259     0.360714     0.934795

# %%
control_scores.describe()
# Out:
#        num_of_features    accuracy  sensitivity  specificity
# count            100.0  100.000000   100.000000   100.000000
# mean             190.0    0.778038     0.387286     0.930936
# std                0.0    0.008172     0.023090     0.008156
# min              190.0    0.754752     0.314286     0.906725
# 25%              190.0    0.773103     0.374554     0.924269
# 50%              190.0    0.777989     0.386607     0.929825
# 75%              190.0    0.784279     0.401786     0.935088
# max              190.0    0.801259     0.450000     0.956725

# %%
control_scores['accuracy'].std()
# Out:
# 0.008171902690537565

# %%
fig = plt.figure(figsize=(10, 10))
ax_acc = fig.add_subplot(311)
ax_acc.set_title('Scores')
ax_acc.errorbar([1, 2], [control_scores['accuracy'].mean(), scores['a_accuracy'].mean()], yerr = [control_scores['accuracy'].std(), scores['a_accuracy'].std()], linestyle='None', marker='o', markerfacecolor='r', ms=10, ecolor='k', capsize=10)
ax_acc.set_xlim((0.5, 2.5))
ax_acc.set_xticks([1, 2])
ax_acc.set_xticklabels(['', ''])
ax_acc.set_ylabel('Accuracy')
ax_sen = fig.add_subplot(312, sharex=ax_acc)
ax_sen.errorbar([1, 2], [control_scores['sensitivity'].mean(), scores['a_sensitivity'].mean()], yerr = [control_scores['sensitivity'].std(), scores['a_sensitivity'].std()], linestyle='None', marker='o', markerfacecolor='g', ms=10, ecolor='k', capsize=10)
ax_sen.set_xlim((0.5, 2.5))
ax_sen.set_xticks([1, 2])
ax_sen.set_xticklabels(['', ''])
ax_sen.set_ylabel('Sensitivity')
ax_spe = fig.add_subplot(313, sharex=ax_acc)
ax_spe.errorbar([1, 2], [control_scores['specificity'].mean(), scores['a_specificity'].mean()], yerr = [control_scores['specificity'].std(), scores['a_specificity'].std()], linestyle='None', marker='o', markerfacecolor='b', ms=10, ecolor='k', capsize=10)
ax_spe.set_xlim((0.5, 2.5))
ax_spe.set_xticks([1, 2])
ax_spe.set_ylabel('Specificity')
ax_spe.set_xticklabels(['Control', 'Experimental'])
plt.savefig('figures/scores.png', dpi=300, format='png')
plt.show()

# %%
t, p = stats.ttest_ind(control_scores['accuracy'], scores['a_accuracy'])
print('Accuracy\n'+'-'*40)
print('    t: {}'.format(t))
print('    p: {}'.format(p))
print()
t, p = stats.ttest_ind(control_scores['sensitivity'], scores['a_sensitivity'])
print('Sensitivity\n'+'-'*40)
print('    t: {}'.format(t))
print('    p: {}'.format(p))
print()
t, p = stats.ttest_ind(control_scores['specificity'], scores['a_specificity'])
print('Specificity\n'+'-'*40)
print('    t: {}'.format(t))
print('    p: {}'.format(p))
# Out:
# Accuracy
# ----------------------------------------
#     t: -20.431367063427658
#     p: 1.1932881481787495e-50
#
# Sensitivity
# ----------------------------------------
#     t: -66.9322207524752
#     p: 6.265591187632975e-138
#
# Specificity
# ----------------------------------------
#     t: 12.025481361671337
#     p: 2.3004228357067834e-25

# %%
best_runs = scores.nlargest(10, 'a_sensitivity')
best_runs
# Out:
#     num_features  a_fitness  a_accuracy  a_sensitivity  a_specificity
# 76          10.0   0.804948    0.825390       0.735714       0.859942
# 7           27.0   0.777922    0.836621       0.710714       0.886257
# 10          21.0   0.770845    0.812809       0.698214       0.858772
# 98          10.0   0.781927    0.817105       0.694643       0.865205
# 27          21.0   0.772742    0.828063       0.692857       0.880702
# 74           8.0   0.789377    0.855755       0.682143       0.923684
# 8           19.0   0.770545    0.831578       0.682143       0.890351
# 68          24.0   0.755551    0.805094       0.678571       0.853801
# 58          31.0   0.740993    0.781128       0.678571       0.821053
# 11          20.0   0.763608    0.832798       0.669643       0.896784

# %%
kin[76]
# Out:
# ['AXL',
#  'CHUK',
#  'EGFR',
#  'IKBKE',
#  'JAK2',
#  'LTK',
#  'PASK',
#  'PDPK1',
#  'ROCK1',
#  'TBK1']

# %%
kin_cnt_df.loc[kin[76]]
# Out:
#        Count  Group
# AXL       14     -1
# CHUK      43     -1
# EGFR      90     13
# IKBKE     18     -1
# JAK2      24     -1
# LTK       25     -1
# PASK      12     -1
# PDPK1      9     -1
# ROCK1     46      1
# TBK1       7     -1

# %%
kin_cnt_ser.head(10)
# Out:
# EGFR     90
# TTK      52
# SIK2     49
# ROCK1    46
# CHUK     43
# ERBB4    39
# ROCK2    37
# MUSK     26
# GSK3A    25
# LTK      25
# dtype: int64

# %%
with open('Rational_Polypharm_Kinase_MAXIS_Frequencies.csv', 'r') as f:
    kinases = next(f).strip().split(',')
    freqs = next(f).strip().split(',')
maxis_kin_cnt = pd.Series(freqs, index=kinases, dtype=int)

# %%
maxis_kin_cnt.sort_values(ascending=False, inplace=True)

# %%
maxis_kin_cnt.head(10)
# Out:
# PIK3CD    100
# EGFR       99
# MAPK11     86
# MAP4K4     70
# MAPK14     67
# TTK        61
# MUSK       58
# ROCK2      56
# FLT4       53
# PDGFRA     53
# dtype: int64
